# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Екатерина, привет!👋</b>
#
# Это Арсен. Здесь стандартный блок с типами комментариев. Большой цифрой в углу комментария буду подписывать номер проверки, на которой его оставил.
#
# <br/>
# <br/>
#
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-success">
#     <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# В случае, если решение на отдельном шаге является полностью правильным.
# </p>
# </div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </p>
# </div>
#
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
#
# <div style="border:solid Chocolate 2px; padding: 10px">
#
# <b>Промежуточный итог</b>
#
# Екатерина, привет!
#
# Очень хорошая работа, ты молодец!
#
# Тем не менее, некоторые моменты надо еще поправить. Комментарии оставил, буду ждать следующий вариант.
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">2</div>
#
# <div style="border:solid Chocolate 2px; padding: 10px">
#
# <b>Промежуточный итог</b>
#
# Екатерина, привет!
#
# В целом почти готово, но несколько моментов еще осталось. Комментарии оставил.
#
# Презентацию, кстати, надо правильную прикрепить, там анализ общепита.
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">3</div>
# <div class="alert alert-success">
# <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
#
# </p>
#     </div>

# %% [markdown]
# # Выявление профилей потребления интернет-магазина "Пока все еще тут"
#
# ## Материалы
#
# [Презентация] (https://disk.yandex.ru/d/jukEYcu9VtSunw)
#
#
# ## Описание исследования
#
# Интернет-магазин товаров для дома «Пока все ещё тут» в срочном порядке ищет аналитиков, которые помогут магазину улучшить текущие процессы путем анализа товарного ассортимента и создания гипотез на основе полученных данных.
#
# Для проведения анализа предоставлен датасет ecommerce_dataset.csv, состоящий из следующих колонок с данными:
# - date — дата заказа;
# - customer_id — идентификатор покупателя;
# - order_id — идентификатор заказа;
# - product — наименование товара;
# - quantity — количество товара в заказе;
# - price — цена товара.
#
# Цель проекта – выявление профилей потребления для последующей оптимизации, сокращения издержек и максимизации прибыли.
#
# Задачи проекта:
# 1)	Импортирование базы данных интернет-магазина ecommerce_dataset.csv за определенный период и библиотек для анализа – pandas, numpy, seaborn, matplotlib.pyplot, datetime, scipy.stats, plotly и др.
#
# 2)	Изучение состава данных с помощью методов info(), describe() и head();
#
# 3)	Проведение предобработки полученных данных – приведение колонок к змеиному регистру, выявление дубликатов, пропусков данных, аномальных (выбивающихся) значений, изучение максимальных, средних, минимальных цен и квартилей, а также корректировка данных – удаление дубликатов и пропущенных значений, а также заполнение пропусков средним (медианным) значением при необходимости;
#
# 4)	Проведение исследовательского анализа данных, включающего в себя следующие шаги:
# - определение количества уникальных пользователей;
# - определение количества уникальных продуктов;
# - определение общего объема полученной выручки;
# - определение периода получения максимальной выручки;
# - определения наличия сезонности при совершении покупок пользователями;
# - группировка товаров по категориям;
# - выявление текущих проблем интернет-магазина;
# - составление графиков и диаграмм по полученным данным.
#
# 5)  Сегментация пользователей на основе истории их покупок:
# - сегментация пользователей по категориям совершенных покупок;
# - сегментация пользователей по среднему чеку;
# - сегментация пользователей по периоду (месяц, день недели, время) совершения покупки.
#
# 6)  Проверка статистических гипотез:
# - Объем полученной выручки в будний день не отличается от объема полученной выручки в выходной день;
# - Средний чек в дневное время не отличается от среднего чека в ночное время.
#
# 7)  Формулирование вывода по проведенному исследованию – описание текущих проблем интернет-магазина и предложение путей их решения.
#
# 8) Подготовка рекомендаций по дальнейшей работе с каждым из выделенных сегментов.
#
#
#
# ## Загрузка и подготовка данных к анализу и изучение общей информации
#
# Импортируем библиотеки: pandas, numpy, seaborn, matplotlib.pyplot, datetime, spicy.stats, plotly, math и сохраним их в качестве переменных pd, plt, sns, np, stats, go, px, pio и mth соответственно.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Екатерина, давай здесь почистим импорты и уберём библиотеки, которые ты не используешь в проекте.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, убрала лишнее и оставила то, что использую в работе.</div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Что-то я не помню в проекте логистической регрессии, решающих деревьев, тестовых выборок и метрик качества)
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, убрала лишнее :) </div>

# %%
import pandas as pd #импортируем библиотеку pandas 
import numpy as np #импортируем библиотеку numpy 
import seaborn as sns #импортируем библиотеку seaborn
import matplotlib.pyplot as plt #импортируем библиотеку matplotlib.pyplot
pd.set_option('display.max_columns', None) #увеличеним максимальное количество отображаемых столбцов таблицы с данными
from datetime import date, datetime, timedelta #импортируем библиотеку datetime
import scipy.stats as st #импортируем библиотеку scipy.stats
from plotly import graph_objects as go #импортируем библиотеку plotly
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly_white"
sns.set(style="whitegrid")
colors =["#ef476f","#ffd166","#06d6a0","#118ab2","#073b4c"]
sns.set_palette(sns.color_palette(colors))
import warnings
warnings.filterwarnings("ignore") 
import math as mth #импортируем библиотеку math
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# Загрузим данные из импортируемого источника ecommerce_dataset.csv, содержащего сведения о совершенных заказах пользователями в интернет-магазине "Пока все еще тут" и сохраним их в соответствующей переменной data.

# %%
try:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv')
except:
    data = pd.read_csv('ecom_dataset_upd.csv')

# %% [markdown]
# Для последующей предобработки данных необходимо посмотреть ключевую информацию о составе источника данных.
#
# Для начала выведем первые 10 строчек таблицы с помощью оператора head() и с помощью оператора info() - основную информацию о таблице с данными и посмотрим количество ненулевых значений в каждом столбце таблицы.

# %%
data.head(10)
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7  2018100108  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8  2018100108  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9  2018100109  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
#
#                                              product  quantity  price
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# ...

# %%
data.info() #выведем ключевую информацию о датасете
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 350.5+ KB

# %%
data.isna().sum() #проверим пропуски данных
# Out:
# date           0
# customer_id    0
# order_id       0
# product        0
# quantity       0
# price          0
# dtype: int64

# %%
data.duplicated().sum() #проверим наличие явных дубликатов в датасете
# Out:
# 0

# %% [markdown]
# Таким образом, мы вывели на экран датасет и увидели, что наименование столбцов приведено к змеиному регистру, явные дубликаты и пропуски в данных отсутствуют. Количество строк в датасете - 7474.
#
# В тоже время мы видим, что данные в столбце date имеют тип int64 вместо datetime. Необходимо привести формат данных в столбце date к нужному типу.

# %%
data['date'] = pd.to_datetime(data['date'], format = '%Y%m%d%H') #приведение данных колонки к типу datetime

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   datetime64[ns]
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 350.5+ KB

# %%
data.head(10)
# Out:
#                  date                           customer_id  order_id  \
# 0 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7 2018-10-01 08:00:00  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8 2018-10-01 08:00:00  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9 2018-10-01 09:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
#
#                                              product  quantity  price
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# ...

# %% [markdown]
# Как видно, колонка date приведена к формату datetime, теперь в ней содержится информация о дате и времени совершения заказа.
# Далее создадим отдельную колонку и перенесем в нее данные о времени совершения заказа, а в колонке date оставим только данные о дате совершения заказа. Дополнительно создадим колонки с днем недели, месяцем и годом.

# %%
data['calendar_date'] = data['date'].dt.date #создание дополнительной колонки calendar_date 
data['time'] = data['date'].dt.time #создание дополнительной колонки time 
data['weekday'] = data['date'].dt.day_name() #создание дополнительной колонки weekday 
data['month'] = data['date'].dt.month_name() #создание дополнительной колонки month 
data['year'] = data['date'].dt.year #создание дополнительной колонки year

# %% [markdown]
# Упорядочим дни недели и месяцы в хронологическом порядке.

# %%
#упорядочим дни недели в хронологическом порядке
weekday = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
data['weekday']=pd.Categorical(data['weekday'], categories=weekday, ordered=True)

#упорядочим месяцы в хронологическом порядке
month = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
data['month']=pd.Categorical(data['month'], categories=month, ordered=True)

# %% [markdown]
# Снова выведем 10 первых строчек датасета, чтобы убедиться в создании перечисленных выше колонок.

# %%
data.head(10)
# Out:
#                  date                           customer_id  order_id  \
# 0 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7 2018-10-01 08:00:00  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8 2018-10-01 08:00:00  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9 2018-10-01 09:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# ...

# %% [markdown]
# С помощью метода describe() выведем статистическую информацию по каждой из колонок таблицы с данными, где в count указано количество строк в столбце, в mean - среднее значение столбца, в std - стандартное отклонение, минимальные (min) и максимальные (max) значения, а также граница каждого квартиля - 25%, 50% и 75%.
#
# С помощью метода round сделаем округление до 2 знаков после запятой.

# %%
round(data.describe(), 2)
# Out:
#         order_id  quantity     price     year
# count    7474.00   7474.00   7474.00  7474.00
# mean    49449.88      2.36    478.74  2018.85
# std     32679.64     14.50    901.62     0.45
# min     12624.00      1.00      9.00  2018.00
# 25%     14833.00      1.00     97.00  2019.00
# 50%     68768.00      1.00    135.00  2019.00
# 75%     71257.75      1.00    439.00  2019.00
# max    112789.00   1000.00  14917.00  2020.00

# %% [markdown]
# Определим самую ранюю и самую позднюю даты в датасете, а также посмотрим на разброс по времени совершения операции.

# %%
print('Самая ранняя дата - ', data['date'].min(), ', самая поздняя дата - ', data['date'].max())
# Out:
# Самая ранняя дата -  2018-10-01 00:00:00 , самая поздняя дата -  2020-01-31 15:00:00

# %%
print('Cамое раннее время: ', data['time'].min(), '. Самое позднее время: ', data['time'].max())
# Out:
# Cамое раннее время:  00:00:00 . Самое позднее время:  23:00:00

# %% [markdown]
# В колонке product наименование продукта содержит данные, записанные как в верхнем, так и в нижнем регистре. Приведем значения в данном столбце к нижнему регистру.

# %%
data['product'] = data['product'].str.lower()

# %% [markdown]
# Таким образом, при изучении общей информации было обнаружено следующее:
#
# 1) наименование столбцов приведено к змеиному регистру;
#
# 2) явные дубликаты и пропуски данных отсутствуют;
#
# 3) формат колонки date был приведен к типу datetime и для целей дальнейшего исследования были добавлены дополнительные колонки. содержащие сведения о дате, времени, дне недели, месяце и годе;
#
# 4) был определен диапазон дат - с 01.10.2018 по 31.01.2020, и времени - от 00:00 до 23:00.
#
# 5) данные в колонке product были приведены к нижнему регистру.
#
#
#
#
# ## Исследовательский анализ данных
#
# Определим количество уникальных пользователей.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Хорошо, что ты после удаления дубликатов повторила эту часть исследовательского анализа, но давай сначала почистим данные, а потом уже будем знакомиться с результатами исследовательской части. С точки зрения процесса исследования ты всё сделала верно, но для представления результатов вот эта часть до очистки дублей уже лишняя.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, убрала предварительный анализ из работы, почистила данные и оставила только очищенные данные для анализа.</div>

# %%
print('Количество уникальных пользователей - ', data['customer_id'].nunique())
# Out:
# Количество уникальных пользователей -  2451

# %% [markdown]
# Определим количество уникальных продуктов.

# %%
print('Количество уникальных продуктов - ', data['product'].nunique())
# Out:
# Количество уникальных продуктов -  2341

# %% [markdown]
# Определим выручку по каждому заказу и сохраним данные по выручке в колонке revenue.

# %%
data['revenue'] = data['quantity'] * data['price']

# %% [markdown]
# Повторно вызовем метод describe() и посмотрим ключевую информацию по столбцам с количеством, ценой и выручкой.

# %%
round(data[['quantity', 'price', 'revenue']].describe(), 2)
# Out:
#        quantity     price    revenue
# count   7474.00   7474.00    7474.00
# mean       2.36    478.74     716.88
# std       14.50    901.62    7939.83
# min        1.00      9.00       9.00
# 25%        1.00     97.00     120.00
# 50%        1.00    135.00     164.00
# 75%        1.00    439.00     614.00
# max     1000.00  14917.00  675000.00

# %% [markdown]
# Из таблицы видно, что медианное значение по выручке составляет 716,88 руб., минимальное - 9 руб., максимальное - 675000 руб. Посмотрим максимальное значение по выручке.

# %%
data[data['revenue'] == 675000]
# Out:
#                     date                           customer_id  order_id  \
# 5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
#
#                                                 product  quantity  price  \
# 5456  вантуз с деревянной ручкой d14 см красный, bur...      1000  675.0
#
#      calendar_date      time  weekday month  year   revenue
# 5456    2019-06-18  15:00:00  Tuesday  June  2019  675000.0

# %% [markdown]
# Таким образом, максимальная выручка была получена 18.06.2019 за заказ на 1000 штук вантуза с деревянной ручной d14 см красный пользователем 312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6.
#
# Далее осуществим проверку по максимальному количеству и цене.

# %%
data[data['quantity'] == 1000]
# Out:
#                     date                           customer_id  order_id  \
# 5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
#
#                                                 product  quantity  price  \
# 5456  вантуз с деревянной ручкой d14 см красный, bur...      1000  675.0
#
#      calendar_date      time  weekday month  year   revenue
# 5456    2019-06-18  15:00:00  Tuesday  June  2019  675000.0

# %%
data[data['price'] == 14917]
# Out:
#                     date                           customer_id  order_id  \
# 5992 2019-07-29 17:00:00  0d87f4ae-465a-4fac-81e6-5d629761783e     72139
#
#                                                 product  quantity    price  \
# 5992  сушилка уличная leifheit 85210 linomatic v 400...         1  14917.0
#
#      calendar_date      time weekday month  year  revenue
# 5992    2019-07-29  17:00:00  Monday  July  2019  14917.0

# %% [markdown]
# Как видно, максимальное количество проданного также относится к заказу вантузов с деревянной ручкой, на которые также пришлось получение максимальной выручки.
#
# А вот максимальная цена зафиксирована на сушилку уличную leifheit 85210 linomatic - 14917 руб./шт. Данная сушилка была продана 29.07.2019 г. пользователю 0d87f4ae-465a-4fac-81e6-5d629761783e.
#
# Для целей дальнейшего исследования необходимо создать колонки с временем года и днем недели совершения покупки. Для этих целей зададим две функции - для определения времени года и дня недели (будний или выходной день).

# %%
def season(month): #зададим функцию для определения времени года
    if  month == "March":
        return 'spring'
    elif month == "April":
        return 'spring'
    elif month == "May": 
        return 'spring'
    elif month == "June":  
        return 'summer'
    elif month == "July":
        return 'summer'
    elif month == "August":
        return 'summer'
    elif month == "September":  
        return 'autumn'
    elif month == "October":
        return 'autumn'
    elif month == "November":
        return 'autumn'
    else:
        return "winter"

# %%
data['season'] = data['month'].apply(season)

# %% [markdown]
# Аналогичным образом создадим функцию, которая поделит дни недели на будние дни и на выходные:

# %%
def weekday_type(weekday): #зададим функцию для классификации дня недели на будние (working day) и выходные (rest day) дни 
    if  weekday == "Saturday": 
        return 'rest day'
    elif weekday == "Sunday":
        return 'rest day'
    else:
        return "working day"

# %%
data['weekday_type'] = data['weekday'].apply(weekday_type)

# %% [markdown]
# Далее проверим с помощью метода unique(), что в колонки season и weekday_type подтянулись все значения из функции:

# %%
data['season'].unique()
# Out:
# array(['autumn', 'winter', 'spring', 'summer'], dtype=object)

# %%
data['weekday_type'].unique()
# Out:
# array(['working day', 'rest day'], dtype=object)

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# Данные по дням недели и времени суток лучше расположить в хронологическом порядке. Так мы легко увидим и наибольшее значение, и динамику в течение дня/недели.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, добавила формулу по сортировке в хронологическом порядке в разделе по предобработке данных.</div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
# <div class="alert alert-success">
# <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# Сам анализ здесь мне нравится, молодец!
# </p>
#     </div>

# %% [markdown]
# Как было озвучено ранее, магазин тестировал крупную закупку вантузов на 1000 штук.
# Для целей дальнейшего исследования удалим данный заказ из выборки, т.к. эта покупка не является физической покупкой и проводилась в учетной системе интернет-магазина исключительно в тестовых целях. Также попробуем выявить другие аномалии, которые, возможно, присутствуют в датасете.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# Вантузы - это не аномалия, это тестовый заказ, мы обсудили это на созвоне. Удалить его действительно необходимо.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Формулировку исправила.</div>

# %%
data = data.drop(labels=[5456], axis=0) #удалим строку с индексом 5465 с вантузами

# %%
data.describe() #убедимся, что удаление прошло успешно с помощью метода describe()
# Out:
#             order_id     quantity         price         year       revenue
# count    7473.000000  7473.000000   7473.000000  7473.000000   7473.000000
# mean    49446.901111     2.229359    478.711238  2018.845711    626.648524
# std     32680.811407     8.779149    901.673367     0.450004   1480.883443
# min     12624.000000     1.000000      9.000000  2018.000000      9.000000
# 25%     14833.000000     1.000000     97.000000  2019.000000    120.000000
# 50%     68768.000000     1.000000    135.000000  2019.000000    164.000000
# 75%     71257.000000     1.000000    439.000000  2019.000000    614.000000
# max    112789.000000   334.000000  14917.000000  2020.000000  49432.000000

# %% [markdown]
# Далее проверим задвоенные данные

# %%
customers_m = data.groupby('order_id').agg({'customer_id':'nunique'}).query('customer_id > 1').reset_index()
customers_m.head()
# Out:
#    order_id  customer_id
# 0     14872            2
# 1     68785            2
# 2     69283            2
# 3     69310            2
# 4     69345            2

# %%
print('Уникальные заказы с разными пользователями:', customers_m.shape[0])
# Out:
# Уникальные заказы с разными пользователями: 29

# %%
data = data.query('order_id not in @customers_m.index')

# %%
orders_m = data.groupby('order_id').agg({'date':'nunique'}).query('date > 1').sort_values(by='date', ascending=False).reset_index()
print('Уникальные заказы с разными датами:', orders_m.shape[0])
# Out:
# Уникальные заказы с разными датами: 284

# %%
orders_m.head()
# Out:
#    order_id  date
# 0     14833    74
# 1     70960    60
# 2     69162    23
# 3     71148    16
# 4     69531    12

# %%
data[data['order_id'] == 70960].head()
# Out:
#                     date                           customer_id  order_id  \
# 2589 2019-04-01 16:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2600 2019-04-02 10:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2622 2019-04-03 08:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2718 2019-04-07 15:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2734 2019-04-08 09:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
#
#                                            product  quantity   price  \
# 2589  сумка-тележка 2-х колесная gimi argo красная         1  1087.0
# 2600  сумка-тележка 2-х колесная gimi argo красная         1  1087.0
# 2622  сумка-тележка 2-х колесная gimi argo красная         1  1087.0
# 2718  сумка-тележка 2-х колесная gimi argo красная         1  1087.0
# 2734  сумка-тележка 2-х колесная gimi argo красная         1  1087.0
#
#      calendar_date      time    weekday  month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 14833].shape[0]
# Out:
# 888

# %% [markdown]
# В датасете имеется 283 уникальных id заказов, даты в которых повторяются. Так, например, заказ номер 14833 представлен в датасете 74 раза в разные даты и занимает 888 строк. Заказ покупателя номер 70960 с одной сумкой-тележкой повторяется 60 раз. Выглядит как техническая ошибка. В связи с тем, что неизвестно, в какое время действительно был совершен заказ пользователями, принимаем решение оставить последнюю дату.
#
# В данных заказах повторяется номер и набор товарных наименований, поэтому удалим дубликаты в этих категориях, сохранив последние в списке.

# %%
data = data.drop_duplicates(subset=['order_id', 'product'], keep='last', inplace=False)

# %%
data[data['order_id'] == 14833]
# Out:
#                     date                           customer_id  order_id  \
# 5533 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5534 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5535 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5536 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5537 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5538 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5539 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5540 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5541 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5542 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5543 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5544 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
#
# ...

# %% [markdown]
# После очищения данных на примере заказа 14833, мы убедились, что осталось 12 товарных уникальных наименований и одна дата совершения покупки.
#
# Далее проверим, остались ли еще дубликаты, которые осталось обработать.

# %%
data.groupby('order_id').agg(
    {'date':'nunique', 'product':'count'}).query('date > 1').sort_values(by='date', ascending=False).reset_index()
# Out:
#     order_id  date  product
# 0      68760     3       21
# 1      14500     2       10
# 2      14541     2        7
# 3      14649     2       15
# 4      14897     2       26
# 5      68814     2        2
# 6      69485     2        2
# 7      69527     2        2
# 8      69750     2        2
# 9      69807     2        2
# 10     70186     2        2
# 11     70318     2        2
# 12     70995     2        2
# 13     71143     2        2
# 14     71426     2        2
# 15     72517     2        2

# %% [markdown]
# По заказам в таблице выше видно, что в некоторых заказах с одинаковой датой содержатся несколько позиций. Проверим каждый из этих заказов на наличие дубликатов.

# %%
data[data['order_id'] == 68760].head()
# Out:
#                    date                           customer_id  order_id  \
# 416 2018-10-26 13:00:00  9f1e7d7d-ff10-4eb1-b596-1cbf8075aa3f     68760
# 418 2018-10-26 13:00:00  9f1e7d7d-ff10-4eb1-b596-1cbf8075aa3f     68760
# 423 2018-10-26 13:00:00  9f1e7d7d-ff10-4eb1-b596-1cbf8075aa3f     68760
# 424 2018-10-26 13:00:00  9f1e7d7d-ff10-4eb1-b596-1cbf8075aa3f     68760
# 427 2018-10-26 13:00:00  9f1e7d7d-ff10-4eb1-b596-1cbf8075aa3f     68760
#
#                                                product  quantity  price  \
# 416  вешалка деревянная с расширенными плечиками и ...         8  262.0
# 418  вешалка с закругленными плечиками без переклад...         7  106.0
# 423  короб стеллажный с крышкой большой, 30*40*25 с...         1  674.0
# 424  короб стеллажный с крышкой малый, 28*30*16 см,...         3  524.0
# 427  набор вешалок мягких тканевых с перекладиной 3...         2  277.0
#
#     calendar_date      time weekday    month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 14500].head()
# Out:
#                    date                           customer_id  order_id  \
# 497 2018-10-28 09:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 499 2018-10-28 09:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 554 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 555 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 556 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
#
#                                                product  quantity  price  \
# 497  рассада зелени для кухни базилик арарат, кассе...         1  169.0
# 499  рассада зелени для кухни розмарина в кассете п...         1  210.0
# 554  многолетнее растение душица-орегано розовый об...         1   89.0
# 555  многолетнее растение тимьян-чабрец розовый объ...         1   89.0
# 556  пеларгония зональная диам. 12 см белая полумах...         1  188.0
#
#     calendar_date      time    weekday    month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 14541].head()
# Out:
#                     date                           customer_id  order_id  \
# 1866 2019-02-17 13:00:00  7e0fb269-d55f-4e36-bcc4-24968b70e009     14541
# 1870 2019-02-17 13:00:00  7e0fb269-d55f-4e36-bcc4-24968b70e009     14541
# 1984 2019-02-24 12:00:00  7e0fb269-d55f-4e36-bcc4-24968b70e009     14541
# 1985 2019-02-24 12:00:00  7e0fb269-d55f-4e36-bcc4-24968b70e009     14541
# 1986 2019-02-24 12:00:00  7e0fb269-d55f-4e36-bcc4-24968b70e009     14541
#
#                                                 product  quantity  price  \
# 1866  рассада зелени для кухни базилик тонус, кассет...         1  169.0
# 1870  рассада зелени для кухни розмарина в горшке ди...         1  120.0
# 1984  рассада зелени для кухни душица-орегано розовы...         1   89.0
# 1985   рассада зелени для кухни мята морокан диам. 9 см         1  120.0
# 1986  рассада зелени для кухни ориганум ауреум голд ...         1  120.0
#
#      calendar_date      time weekday     month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 14649].head()
# Out:
#                     date                           customer_id  order_id  \
# 2874 2019-04-16 13:00:00  0184f535-b60a-4914-a982-231e3f615206     14649
# 2891 2019-04-16 16:00:00  0184f535-b60a-4914-a982-231e3f615206     14649
# 2892 2019-04-16 16:00:00  0184f535-b60a-4914-a982-231e3f615206     14649
# 2893 2019-04-16 16:00:00  0184f535-b60a-4914-a982-231e3f615206     14649
# 2894 2019-04-16 16:00:00  0184f535-b60a-4914-a982-231e3f615206     14649
#
#                                                 product  quantity  price  \
# 2874  виола рассада однолетних цветов в кассете по 1...         1  210.0
# 2891  бакопа ампельная махровая сиреневая махровая о...         1   90.0
# 2892  бакопа ампельная махровая фиолетовая махровая ...         1   90.0
# 2893  газания рассада однолетних цветов в кассете по...         1  210.0
# 2894  калибрахоа aloha double purple сиреневая махро...         1   90.0
#
#      calendar_date      time  weekday  month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 14897].head()
# Out:
#                     date                           customer_id  order_id  \
# 5773 2019-07-10 09:00:00  42d3cb27-6519-4627-9b4a-5aa8ee600203     14897
# 5774 2019-07-10 09:00:00  42d3cb27-6519-4627-9b4a-5aa8ee600203     14897
# 5775 2019-07-10 09:00:00  42d3cb27-6519-4627-9b4a-5aa8ee600203     14897
# 5783 2019-07-10 09:00:00  42d3cb27-6519-4627-9b4a-5aa8ee600203     14897
# 5784 2019-07-10 09:00:00  42d3cb27-6519-4627-9b4a-5aa8ee600203     14897
#
#                                                 product  quantity  price  \
# 5773                       декабрист в горшке d12 белый         1  139.0
# 5774                   декабрист в горшке d12 малиновый         1  139.0
# 5775                 декабрист в горшке d12 цвет фуксии         1  139.0
# 5783  томата (помидор) арбузный №5 сорт индетерминан...         1   38.0
# 5784  томата (помидор) болгарска хала №9 сорт индете...         1   38.0
#
#      calendar_date      time    weekday month  year  revenue  season  \
# ...

# %%
data[data['order_id'] == 68814].head()
# Out:
#                     date                           customer_id  order_id  \
# 565  2018-10-31 17:00:00  5580760e-3857-4710-b4a5-70c29aa54342     68814
# 1327 2018-12-23 18:00:00  5580760e-3857-4710-b4a5-70c29aa54342     68814
#
#                                                 product  quantity  price  \
# 565   холодная сварка mastix 55г для труб и батарей,...         1   44.0
# 1327  холодная сварка mastix 55г универсальная, 1205037         2   52.0
#
#      calendar_date      time    weekday     month  year  revenue  season  \
# 565     2018-10-31  17:00:00  Wednesday   October  2018     44.0  autumn
# 1327    2018-12-23  18:00:00     Sunday  December  2018    104.0  winter
#
#      weekday_type
# 565   working day
# 1327     rest day

# %%
data[data['order_id'] == 69485].head()
# Out:
#                     date                           customer_id  order_id  \
# 1282 2018-12-20 16:00:00  5be0f4b4-947f-4672-b147-73ef5936ecd4     69485
# 1384 2018-12-26 23:00:00  e0461045-4fcc-4731-8837-509f6534512a     69485
#
#                                                 product  quantity   price  \
# 1282  набор столовых приборов 24 предмета saint germ...         1  1087.0
# 1384  набор столовых приборов 24 предмета farandole ...         1  1274.0
#
#      calendar_date      time    weekday     month  year  revenue  season  \
# 1282    2018-12-20  16:00:00   Thursday  December  2018   1087.0  winter
# 1384    2018-12-26  23:00:00  Wednesday  December  2018   1274.0  winter
#
#      weekday_type
# 1282  working day
# 1384  working day

# %%
data[data['order_id'] == 69527].head()
# Out:
#                     date                           customer_id  order_id  \
# 1340 2018-12-24 09:00:00  eb04c06f-bee9-45bd-9392-4addbc54952f     69527
# 1434 2019-01-03 22:00:00  eb04c06f-bee9-45bd-9392-4addbc54952f     69527
#
#                                                 product  quantity   price  \
# 1340  плед флисовый 200х150 см wellness wplny152-зим...         1   712.0
# 1434  лестница-стремянка dogrular ufuk оцинкованная ...         1  1649.0
#
#      calendar_date      time   weekday     month  year  revenue  season  \
# 1340    2018-12-24  09:00:00    Monday  December  2018    712.0  winter
# 1434    2019-01-03  22:00:00  Thursday   January  2019   1649.0  winter
#
#      weekday_type
# 1340  working day
# 1434  working day

# %%
data[data['order_id'] == 69750].head()
# Out:
#                     date                           customer_id  order_id  \
# 1460 2019-01-09 14:00:00  d247211c-d16b-43ba-812d-6a27aff31871     69750
# 1814 2019-02-13 12:00:00  d247211c-d16b-43ba-812d-6a27aff31871     69750
#
#                                                 product  quantity   price  \
# 1460  сумка-тележка хозяйственная gimi rolling therm...         1  2999.0
# 1814  сумка-тележка хозяйственная gimi rolling therm...         1  2999.0
#
#      calendar_date      time    weekday     month  year  revenue  season  \
# 1460    2019-01-09  14:00:00  Wednesday   January  2019   2999.0  winter
# 1814    2019-02-13  12:00:00  Wednesday  February  2019   2999.0  winter
#
#      weekday_type
# 1460  working day
# 1814  working day

# %%
data[data['order_id'] == 69807].head()
# Out:
#                     date                           customer_id  order_id  \
# 1508 2019-01-14 08:00:00  0982f6b9-328f-4a67-b7ee-cd0a114868f0     69807
# 1807 2019-02-12 21:00:00  0982f6b9-328f-4a67-b7ee-cd0a114868f0     69807
#
#                                                 product  quantity  price  \
# 1508  контейнер для свч полимербыт премиум 1,2 л 435...         1   59.0
# 1807       стремянка металлическая 3 ступени, см3, ника         1  899.0
#
#      calendar_date      time  weekday     month  year  revenue  season  \
# 1508    2019-01-14  08:00:00   Monday   January  2019     59.0  winter
# 1807    2019-02-12  21:00:00  Tuesday  February  2019    899.0  winter
#
#      weekday_type
# 1508  working day
# 1807  working day

# %%
data[data['order_id'] == 70186].head()
# Out:
#                     date                           customer_id  order_id  \
# 1765 2019-02-10 10:00:00  0a4e4711-5cb7-4bae-93cf-6731902708de     70186
# 1802 2019-02-12 17:00:00  0a4e4711-5cb7-4bae-93cf-6731902708de     70186
#
#                                               product  quantity   price  \
# 1765  комнатное растение в горшке алое вера, d12, h30         1   142.0
# 1802          гладильная доска ника бест 122х40 см нб         1  1574.0
#
#      calendar_date      time  weekday     month  year  revenue  season  \
# 1765    2019-02-10  10:00:00   Sunday  February  2019    142.0  winter
# 1802    2019-02-12  17:00:00  Tuesday  February  2019   1574.0  winter
#
#      weekday_type
# 1765     rest day
# 1802  working day

# %%
data[data['order_id'] == 70318].head()
# Out:
#                     date                           customer_id  order_id  \
# 1886 2019-02-18 11:00:00  2c4cdb89-9a38-40f5-9c36-109d2bf78cbe     70318
# 1938 2019-02-21 13:00:00  2c4cdb89-9a38-40f5-9c36-109d2bf78cbe     70318
#
#                                                 product  quantity   price  \
# 1886  гладильная доска dogrular домина 125х42 см 223708         1  1574.0
# 1938  сковорода алюминиевая с антипригарным покрытие...         1   637.0
#
#      calendar_date      time   weekday     month  year  revenue  season  \
# 1886    2019-02-18  11:00:00    Monday  February  2019   1574.0  winter
# 1938    2019-02-21  13:00:00  Thursday  February  2019    637.0  winter
#
#      weekday_type
# 1886  working day
# 1938  working day

# %%
data[data['order_id'] == 70995].head()
# Out:
#                     date                           customer_id  order_id  \
# 2632 2019-04-03 17:00:00  cfc1fd9f-ac10-417d-aad8-ce5fcbc4d786     70995
# 2743 2019-04-08 15:00:00  cfc1fd9f-ac10-417d-aad8-ce5fcbc4d786     70995
#
#                                                 product  quantity  price  \
# 2632  чехол для гладильной доски zalger 520133 120х4...         1  239.0
# 2743     настенная сушилка для белья gimi brio super 80         1  749.0
#
#      calendar_date      time    weekday  month  year  revenue  season  \
# 2632    2019-04-03  17:00:00  Wednesday  April  2019    239.0  spring
# 2743    2019-04-08  15:00:00     Monday  April  2019    749.0  spring
#
#      weekday_type
# 2632  working day
# 2743  working day

# %%
data[data['order_id'] == 71143].head()
# Out:
#                     date                           customer_id  order_id  \
# 2850 2019-04-15 07:00:00  1772d490-ef94-4d83-9bb1-9a12aebbe3ce     71143
# 2948 2019-04-18 15:00:00  1772d490-ef94-4d83-9bb1-9a12aebbe3ce     71143
#
#                                   product  quantity  price calendar_date  \
# 2850  муляж банан желтый 21 см полиуретан         1   59.0    2019-04-15
# 2948       муляж апельсин 8 см полиуретан         1   59.0    2019-04-18
#
#           time   weekday  month  year  revenue  season weekday_type
# 2850  07:00:00    Monday  April  2019     59.0  spring  working day
# 2948  15:00:00  Thursday  April  2019     59.0  spring  working day

# %%
data[data['order_id'] == 71426].head()
# Out:
#                     date                           customer_id  order_id  \
# 3789 2019-05-14 16:00:00  d05e3c48-3745-408e-8880-d787e06062ae     71426
# 3797 2019-05-15 00:00:00  d05e3c48-3745-408e-8880-d787e06062ae     71426
#
#                                                 product  quantity   price  \
# 3789  стремянка colombo factotum 3 ступени алюминий ...         1  1949.0
# 3797  стремянка colombo factotum 3 ступени стальная ...         1  1949.0
#
#      calendar_date      time    weekday month  year  revenue  season  \
# 3789    2019-05-14  16:00:00    Tuesday   May  2019   1949.0  spring
# 3797    2019-05-15  00:00:00  Wednesday   May  2019   1949.0  spring
#
#      weekday_type
# 3789  working day
# 3797  working day

# %%
data[data['order_id'] == 72517].head()
# Out:
#                     date                           customer_id  order_id  \
# 6258 2019-09-05 14:00:00  51851f8e-e239-4e31-ab2c-4b67ab2c76da     72517
# 6263 2019-09-05 22:00:00  51851f8e-e239-4e31-ab2c-4b67ab2c76da     72517
#
#                                             product  quantity  price  \
# 6258     бальзамин новогвинейский d-13 см лососевый         1  134.0
# 6263  бальзамин новогвинейский d-13 см ярко красный         1  134.0
#
#      calendar_date      time   weekday      month  year  revenue  season  \
# 6258    2019-09-05  14:00:00  Thursday  September  2019    134.0  autumn
# 6263    2019-09-05  22:00:00  Thursday  September  2019    134.0  autumn
#
#      weekday_type
# 6258  working day
# 6263  working day

# %% [markdown]
# Таким образом, мы проверили заказы и убедились в том, что дубликаты в них отсутствуют. В данных заказах содержались несколько отличных друг от друга товаров одновременно. Данные заказы очищать от дубликатов не будем.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Судя по ячейке выше, у нас еще остались заказы, у которых более одной даты. Надо посмотреть на них поближе, чтобы понять, можем ли мы их оставить в таком виде.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, посмотрела выше каждый из оставшихся заказов и убедилась в том, что дубликатов в заказах нет, в каждом из заказов содержалось несколько категорий отличных друг от друга товаров. Удалять из выборки данные заказы не будем.</div>

# %%
data.shape[0]
# Out:
# 5553

# %%
data.describe()
# Out:
#             order_id     quantity         price         year       revenue
# count    5553.000000  5553.000000   5553.000000  5553.000000   5553.000000
# mean    55979.904916     2.406627    531.613377  2018.829281    709.546987
# std     32442.518889     9.597875    974.387052     0.488366   1655.569150
# min     12624.000000     1.000000      9.000000  2018.000000      9.000000
# 25%     14810.000000     1.000000     90.000000  2019.000000    120.000000
# 50%     69205.000000     1.000000    150.000000  2019.000000    191.000000
# 75%     71937.000000     1.000000    524.000000  2019.000000    734.000000
# max    112789.000000   334.000000  14917.000000  2020.000000  49432.000000

# %% [markdown]
# Таким образом, после обработки данных и удаления неявных дубликатов и выбивающегося значения с 1000 вантузами, было получено 5553 строки с данными.
#
# Определим объем выручки, уникальных пользователей и продуктов после удаления дубликатов и тестового заказа.

# %%
data['revenue'] = data['quantity'] * data['price']
print('Общая выручка за период составляет ', data['revenue'].sum().round(2), ' руб.')
print('Количество уникальных пользователей: ', data['customer_id'].nunique())
print('Количество уникальных продуктов: ', data['product'].nunique())
# Out:
# Общая выручка за период составляет  3940114.42  руб.
# Количество уникальных пользователей:  2429
# Количество уникальных продуктов:  2340

# %% [markdown]
# Определим среднее количество покупателей за период (месяц, неделю, день), среднее количество заказов, средний чек на покупателя.

# %%
# посчитаем среднее кол-во покупателей
mau_data = data.groupby('month').agg({'customer_id': 'nunique'}).mean()
wau_data = data.groupby('weekday').agg({'customer_id': 'nunique'}).mean()
dau_data = data.groupby('calendar_date').agg({'customer_id': 'nunique'}).mean()

print('Среднее количество уникальных клиентов:')
print('- в месяц', int(mau_data))
print('- в неделю', int(wau_data))
print('- в день', int(dau_data))

revenue_avg = data.groupby('customer_id').agg({'revenue':'sum'}).mean()
print('Средний чек заказа: {} руб.'.format(int(revenue_avg)))

sticky_wau = (dau_data / wau_data) * 100
sticky_mau = (dau_data / mau_data) * 100
print('Недельная аудитория: {:0.2f}%'.format(sticky_wau[0]))
print('Месячная аудитория: {:0.2f}%'.format(sticky_mau[0]))

order = data.groupby('calendar_date').agg({'order_id': ['count']}).count().mean().round(2)
print('Среднее количество заказов в день: ', order)
# Out:
# Среднее количество уникальных клиентов:
# - в месяц 263
# - в неделю 452
# - в день 6
# Средний чек заказа: 1622 руб.
# Недельная аудитория: 1.54%
# Месячная аудитория: 2.64%
# Среднее количество заказов в день:  485.0

# %% [markdown]
# Определим средний чек в зависимости от года, месяца, дня недели и времени суток.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Обрати внимание, у нас в датасете может быть несколько строк на один заказ, если в нём оформили несколько товаров. Поэтому для расчета среднего чека мы не можем взять построчное среднее по выручке, нам надо сначала посчитать стоимость каждого заказа, а потом уже от этих значений взять среднее. Дальше про это писать уже не буду, но это надо везде поправить.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, ниже поправила формулы.</div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь немного не дожали.
#
# Нам надо посчитать стоимость каждого заказа. Если в нём одна строчка на тысячу, то результат mean() и sum() не будет отличаться, но если в нём десять строчек по сто, то при реальной сумме заказа в 1000 рублей, используя mean, мы получим 100, что будет неверно.
#
# В общем, здесь (и далее) надо использовать {'revenue': 'sum'} для расчета стоимость каждого заказа, а если нам дальше надо найти средний чек в табличном виде, то добавляем еще одну группировку по году и там уже берём mean. Что-то типа такого:
#
#     data.groupby(['year','order_id'], as_index=False).agg({'revenue':'sum'}).groupby('year').revenue.mean()
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Спасибо большое за формулу.</div>

# %%
#определим средний чек по годам
avg_bill_by_year = data.groupby(['year','order_id'], as_index=False).agg({'revenue':'sum'}).groupby('year').revenue.mean().reset_index().round(2)
avg_bill_by_year
# Out:
#    year  revenue
# 0  2018  1464.63
# 1  2019  1070.76
# 2  2020   646.98

# %%
#построим график с среднего чека по годам
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = avg_bill_by_year, x='year', y='revenue').set_title('Средний чек интернет-магазина по годам');
plt.xlabel("Период, год");
plt.ylabel("Средний чек, руб.");

# %% [markdown]
# Наибольший средний чек был в 2018 году, наименьший в 2020 году.

# %%
#определим средний чек по времени года
avg_bill_by_season = data.groupby(['season', 'order_id'], as_index=False).agg({'revenue':'sum'}).groupby(['season']).revenue.mean().sort_values(ascending=False).reset_index().round(2)
avg_bill_by_season
# Out:
#    season  revenue
# 0  summer  1201.70
# 1  autumn  1177.83
# 2  spring  1159.02
# 3  winter  1012.16

# %%
#построим график с среднего чека по времени года
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = avg_bill_by_season, x='season', y='revenue').set_title('Средний чек интернет-магазина по времени года');
plt.xlabel("Время года");
plt.ylabel("Средний чек, руб.");

# %% [markdown]
# Наибольший средний чек по времени года приходится на летний сезон, далее следуют осень и весна. На зиму приходится самый низкий средний чек.

# %%
#определим средний чек по месяцу
avg_bill_by_month = data.groupby(['month', 'order_id']).agg({'revenue':'sum'}).groupby(['month']).revenue.mean().reset_index().round(2)
avg_bill_by_month
# Out:
#         month  revenue
# 0     January   116.12
# 1    February    86.95
# 2       March    72.64
# 3       April    89.97
# 4         May    65.57
# 5        June    66.85
# 6        July    64.31
# 7      August    51.49
# 8   September    50.99
# 9     October   159.88
# 10   November   138.80
# 11   December   155.78

# %%
#построим график с среднего чека по месяцу
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = avg_bill_by_month, x='month', y='revenue').set_title('Средний чек интернет-магазина по месяцу');
plt.xlabel("Месяц");
plt.ylabel("Средний чек, руб.");

# %% [markdown]
# Наибольший средний чек по месяцам в октябре, ноябре и декабре, наименьший средний чек - в августе и сентябре.

# %%
#определим средний чек по дню недели
avg_bill_by_weekday = data.groupby(['weekday', 'order_id']).agg({'revenue':'sum'}).groupby(['weekday']).revenue.mean().reset_index().round(2)
avg_bill_by_weekday
# Out:
#      weekday  revenue
# 0     Monday   189.04
# 1    Tuesday   217.15
# 2  Wednesday   165.15
# 3   Thursday   177.04
# 4     Friday   162.08
# 5   Saturday    92.81
# 6     Sunday   116.08

# %%
#построим график с среднего чека по дню недели
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = avg_bill_by_weekday, x='weekday', y='revenue').set_title('Средний чек интернет-магазина по дням недели');
plt.xlabel("День недели");
plt.ylabel("Средний чек, руб.");

# %% [markdown]
# Наибольший средний чек по дням недели - во вторник, понедельник, четверг, далее следуют среда и пятница, наименьший - в субботу и воскресенье.

# %%
#определим средний чек по времени суток
avg_bill_by_time = data.groupby(['time', 'order_id']).agg({'revenue':'sum'}).groupby('time').revenue.mean().reset_index().round(2)
avg_bill_by_time
# Out:
#         time  revenue
# 0   00:00:00   823.04
# 1   01:00:00   827.58
# 2   02:00:00  1138.96
# 3   03:00:00  1022.82
# 4   04:00:00   985.47
# 5   05:00:00  1016.28
# 6   06:00:00  1446.16
# 7   07:00:00  1969.72
# 8   08:00:00  1195.13
# 9   09:00:00  1115.01
# 10  10:00:00   985.52
# 11  11:00:00  1091.11
# 12  12:00:00  1071.43
# 13  13:00:00  1248.51
# 14  14:00:00   999.35
# 15  15:00:00  1106.29
# 16  16:00:00  1219.73
# 17  17:00:00  1412.73
# 18  18:00:00  1244.94
# 19  19:00:00  1077.07
# 20  20:00:00   962.50
# 21  21:00:00   990.16
# 22  22:00:00   971.97
# 23  23:00:00   727.49

# %%
#построим график с среднего чека по времени суток
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = avg_bill_by_time, x='time', y='revenue').set_title('Средний чек интернет-магазина по времени суток');
plt.xlabel("Время суток");
plt.ylabel("Средний чек, руб.");

# %% [markdown]
# Наибольший средний чек по времени суток в 07:00, 06:00, 17:00, 13:00 и 18:00. Пиковое значение среднего чека приходится на 07:00. Наименьший средний чек в 01:00, 00:00 и 23:00.
#
# Оценим динамику изменения количества уникальных пользователей во времени

# %%
data.groupby('calendar_date').agg({'customer_id':'nunique'}).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в день')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь уже точно надо упорядочить дни недели.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, дни недели и месяцы упорядочены, формулу добавила в раздел по предобработке данных.</div>

# %%
data.groupby('weekday').agg({'customer_id':'nunique'}).sort_values(by='weekday', ascending=True).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в неделю')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# А здесь у нас искажается метрика из-за неодинакового количества месяцев в году, в наших данных лучше рассматривать в связке год+месяц.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, сделала привязку месяц+год на графике.</div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">2</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# Здесь и дальше из-за перехода на категориальный тип криво отображаются в виде нолей вот эти данные, которых у нас нет.
#
# Исправлять уже не обязательно, на это можно закрыть глаза, но вообще так лучше не делать. Один из вариантов - ограничить диапазон отображения по x, или просто задать до отображения фильтр query('customer_id > 0').
# </p>
# </div>

# %%
data.groupby(['year','month']).agg({'customer_id':'nunique'}).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в месяц')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# В декабре и с февраля по апрель число уникальных покупателей наиболее высоко. В январские праздники спрос на продукцию магазина резко падает. То же самое происходит в июне. Вероятно, в середине дачного сезона уже не принято активно закупаться онлайн. Клиенты либо уже приобрели все необходимое, либо предпочтут офлайн магазин для более скорого результата. Тем не менее, в июле активность среди посетителей растет.
#
# Далее определим суммарную выручку по годам, времени года, месяцам, дням недели и времени суток.

# %%
revenue_by_years = data.groupby(['year'])['revenue'].sum().reset_index().sort_values(by='revenue', ascending=False).round(2)
revenue_by_years #определим выручку по годам
# Out:
#    year     revenue
# 1  2019  2710083.08
# 0  2018  1055995.00
# 2  2020   174036.33

# %%
customers_by_years = data.groupby(['year'])['customer_id'].nunique().reset_index().sort_values(by='customer_id', ascending=False).round(2)
customers_by_years #определим количество пользователей по годам
# Out:
#    year  customer_id
# 1  2019         2021
# 0  2018          585
# 2  2020          269

# %%
#построим график получения суммарной выручки по годам
sns.set_style('whitegrid');
plt.figure(figsize=(20, 10));
ax = sns.barplot(data = revenue_by_years, x='year', y='revenue').set_title('Суммарная выручка интернет-магазина по годам');
plt.xlabel("Период получения выручки, год");
plt.ylabel("Объем выручки, млн. руб.");

#построим график с отображением суммарного количества клиентов по годам
sns.set_style('whitegrid');
plt.figure(figsize=(20, 10));
ax = sns.barplot(data = customers_by_years, x='year', y='customer_id').set_title('Суммарное количество клиентов интернет-магазина по годам');
plt.xlabel("Период, год");
plt.ylabel("Количество клиентов");

# %% [markdown]
# На данном графике существенного изменения нет: период получения наибольшей выручки в 2019 г.
# В 2019 г. количество клиентов составило 4067 человек, в 4 квартале 2018 г. - 1217 человек, в январе 2020 г. - 269 человек.
#
# Далее отследим динамику получения выручки и определим количество клиентов по месяцам.

# %%
revenue_by_months = data.groupby(['year', 'month'])['revenue'].sum().reset_index().sort_values(by='revenue', ascending=False).round(2)
revenue_by_months #определим выручку по месяцам
# Out:
#     year      month    revenue
# 10  2018   November  359772.00
# 9   2018    October  350748.00
# 11  2018   December  345475.00
# 15  2019      April  316691.00
# 13  2019   February  306059.00
# 14  2019      March  255704.00
# 17  2019       June  235319.00
# 12  2019    January  234715.00
# 16  2019        May  230806.00
# 18  2019       July  226361.00
# 21  2019    October  212040.00
# 23  2019   December  202885.33
# 19  2019     August  181231.00
# 20  2019  September  179480.00
# 24  2020    January  174036.33
# 22  2019   November  128791.75
# 28  2020        May       0.00
# 29  2020       June       0.00
# 26  2020      March       0.00
# 30  2020       July       0.00
# 31  2020     August       0.00
# 32  2020  September       0.00
# 33  2020    October       0.00
# 34  2020   November       0.00
# 27  2020      April       0.00
# 0   2018    January       0.00
# 25  2020   February       0.00
# 1   2018   February       0.00
# 8   2018  September       0.00
# ...

# %%
customers_by_months = data.groupby(['year', 'month'])['customer_id'].nunique().reset_index().sort_values(by='customer_id', ascending=False).round(2)
customers_by_months #определим количество клиентов по месяцам
# Out:
#     year      month  customer_id
# 24  2020    January          269
# 23  2019   December          246
# 13  2019   February          246
# 15  2019      April          236
# 14  2019      March          233
# 11  2018   December          231
# 22  2019   November          217
# 18  2019       July          185
# 9   2018    October          179
# 10  2018   November          178
# 21  2019    October          177
# 20  2019  September          173
# 16  2019        May          166
# 19  2019     August          166
# 17  2019       June          153
# 12  2019    January          152
# 32  2020  September            0
# 31  2020     August            0
# 27  2020      April            0
# 30  2020       July            0
# 26  2020      March            0
# 29  2020       June            0
# 33  2020    October            0
# 34  2020   November            0
# 28  2020        May            0
# 0   2018    January            0
# 25  2020   February            0
# ...

# %%
#построим график с отображением суммарной выручки по месяцам
sns.set_style('whitegrid');
plt.figure(figsize=(20, 10));
ax = sns.barplot(data = revenue_by_months, x='revenue', y='month', hue = 'year').set_title('Выручка интернет-магазина за период 01.10.2018-31.01.2020 гг.');
plt.xlabel("Объем выручки, млн. руб.");
plt.ylabel("Период получения выручки, месяц");

#построим график с отображением суммарного количества клиентов по месяцам
sns.set_style('whitegrid');
plt.figure(figsize=(20, 10));
ax = sns.barplot(data = customers_by_months, x='customer_id', y='month', hue = 'year').set_title('Пользователи интернет-магазина за период 01.10.2018-31.01.2020 гг.');
plt.xlabel("Количество клиентов");
plt.ylabel("Период, месяц");

# %% [markdown]
# После удаления строки с вантузами и неявных дубликатов видно, что максимальная выручка была получена в ноябре, октябре и декабре 2018 г., апреле, феврале, марте 2019 г.. Минимальная выручка была в августе, сентябре и ноябре 2019 г. и январе 2020 г.
#
# При анализе количества клиентов видно, что максимальное количество клиентов приходилось на февраль, декабрь и апрель 2019 г. Минимальное количество клиентов - в январе, июне, августе и сентябре 2019 г.
#
# Далее посмотрим на выручку и количество клиентов интернет-магазина по времени года.

# %%
revenue_by_season = data.groupby(['season', 'year'])['revenue'].sum().reset_index().sort_values(by = 'revenue', ascending=True).round(2)
revenue_by_season #определим выручку по времени года
# Out:
#    season  year    revenue
# 6  winter  2020  174036.33
# 4  winter  2018  345475.00
# 1  autumn  2019  520311.75
# 3  summer  2019  642911.00
# 0  autumn  2018  710520.00
# 5  winter  2019  743659.33
# 2  spring  2019  803201.00

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь мы вместо клиентов посчитали строки в датасете. Чтобы этого избежать, надо использовать nunique() вместо count.
#
# Дальше это тоже есть, надо везде проверить.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, заменила count на nunique.</div>

# %%
customers_by_season = data.groupby(['season', 'year'])['customer_id'].nunique().reset_index().sort_values(by = 'customer_id', ascending=True).round(2)
customers_by_season #определим количество клиентов по времени года
# Out:
#    season  year  customer_id
# 4  winter  2018          231
# 6  winter  2020          269
# 0  autumn  2018          356
# 3  summer  2019          499
# 5  winter  2019          539
# 1  autumn  2019          565
# 2  spring  2019          623

# %%
#построим график с отображением суммарной выручки по времени года
fig = px.bar(revenue_by_season,
             x='revenue',
             y='season',
             text = 'revenue',
             template='plotly_white', 
             color='year'
            )
# оформляем график
fig.update_layout(title='Выручка интернет-магазина в зависимости от времени года ',
                   xaxis_title='Объем выручки',
                   yaxis_title='Время года',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=True)
fig.show()

#построим график с отображением суммарного количества клиентов по времени года
fig = px.bar(customers_by_season,
             x='customer_id',
             y='season',
             text = 'customer_id',
             template='plotly_white', 
             color='year'
            )
# оформляем график
fig.update_layout(title='Клиенты интернет-магазина в зависимости от времени года ',
                   xaxis_title='Количество клиентов',
                   yaxis_title='Время года',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=True)
fig.show()
# Out:
# <div>                            <div id="be4bb258-37de-4472-9139-d56b70a26a4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be4bb258-37de-4472-9139-d56b70a26a4a")) {                    Plotly.newPlot(                        "be4bb258-37de-4472-9139-d56b70a26a4a",                        [{"alignmentgroup":"True","hovertemplate":"revenue=%{text}<br>season=%{y}<br>year=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2020,2018,2019,2019,2018,2019,2019],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[174036.33,345475.0,520311.75,642911.0,710520.0,743659.33,803201.0],"textposition":"auto","x":[174036.33,345475.0,520311.75,642911.0,710520.0,743659.33,803201.0],"
# ...

# %% [markdown]
# После удаления тестового заказа и неявных дубликатов также видно, что максимальную выручку магазин получил весной, зимой 2019 г. и осенью 2018 г. Минимальную выручку магазин получил осенью 2019 г., зимой 2018 и 2020 гг.
#
# При анализе количества клиентов интернет-магазина было обнаружено, что максимальное количество клиентов приходится на весну, осень и зиму 2019 г. - 623, 565, 539 человека соответственно. Наименьшее количество клиентов приходится на осень 2018 г. - 356 человек, зиму 2018 и 2020 гг. - 231 и 269 человек соответственно.
#
# Далее проследим, как изменилась динамика получения выручки по дням недели после удаления операции с вантузами и неявных дубликатов и определим количество пользователей по дням недели.

# %%
revenue_by_weekday = data.groupby(['weekday', 'year'])['revenue'].sum().reset_index().sort_values(by = 'revenue', ascending=True).round(2)
revenue_by_weekday #определим выручку по дням недели
# Out:
#       weekday  year    revenue
# 2      Monday  2020   10674.50
# 5     Tuesday  2020   21060.50
# 17   Saturday  2020   21809.00
# 14     Friday  2020   26127.00
# 20     Sunday  2020   30201.67
# 11   Thursday  2020   31869.33
# 8   Wednesday  2020   32294.33
# 15   Saturday  2018   71064.00
# 18     Sunday  2018  110455.00
# 6   Wednesday  2018  140992.00
# 12     Friday  2018  167169.00
# 9    Thursday  2018  174655.00
# 0      Monday  2018  184537.00
# 3     Tuesday  2018  207123.00
# 16   Saturday  2019  233822.00
# 19     Sunday  2019  267939.83
# 13     Friday  2019  377231.75
# 7   Wednesday  2019  408030.83
# 10   Thursday  2019  416646.50
# 1      Monday  2019  470214.17
# 4     Tuesday  2019  536198.00

# %%
customers_by_weekday = data.groupby(['weekday', 'year'])['customer_id'].nunique().reset_index().sort_values(by = 'customer_id', ascending=True).round(2)
customers_by_weekday #определим количество клиентов по дням недели
# Out:
#       weekday  year  customer_id
# 2      Monday  2020           28
# 5     Tuesday  2020           32
# 17   Saturday  2020           36
# 14     Friday  2020           36
# 20     Sunday  2020           39
# 11   Thursday  2020           48
# 8   Wednesday  2020           50
# 15   Saturday  2018           65
# 9    Thursday  2018           82
# 18     Sunday  2018           83
# 12     Friday  2018           84
# 6   Wednesday  2018           89
# 0      Monday  2018           94
# 3     Tuesday  2018          107
# 16   Saturday  2019          231
# 19     Sunday  2019          300
# 13     Friday  2019          306
# 7   Wednesday  2019          345
# 10   Thursday  2019          383
# 4     Tuesday  2019          398
# 1      Monday  2019          405

# %%
#построим график с отображением суммарной выручки по дням недели
fig = px.bar(revenue_by_weekday,
             x='revenue',
             y='weekday',
             text = 'revenue',
             template='plotly_white', 
             color='year'
            )
# оформляем график
fig.update_layout(title='Выручка интернет-магазина в зависимости от дня недели ',
                   xaxis_title='Объем выручки',
                   yaxis_title='День недели',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=True)
fig.show()

#построим график с отображением суммарного количества клиентов по дням недели
fig = px.bar(customers_by_weekday,
             x='customer_id',
             y='weekday',
             text = 'customer_id',
             template='plotly_white', 
             color='year'
            )
# оформляем график
fig.update_layout(title='Количество пользователей интернет-магазина в зависимости от дня недели ',
                   xaxis_title='Количество пользователей',
                   yaxis_title='День недели',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=True)
fig.show()
# Out:
# <div>                            <div id="172593e1-3340-4339-a75a-8197fb351a74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("172593e1-3340-4339-a75a-8197fb351a74")) {                    Plotly.newPlot(                        "172593e1-3340-4339-a75a-8197fb351a74",                        [{"alignmentgroup":"True","hovertemplate":"revenue=%{text}<br>weekday=%{y}<br>year=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2020,2020,2020,2020,2020,2020,2020,2018,2018,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2019,2019],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[10674.5,21060.5,21809.0,26127.0,30201.67,31869.33,32294.33,71064.0,110455.0,140992.0,167169
# ...

# %% [markdown]
# График по выручке по дням недели после удаления аномалии изменился несильно - в 2019 г. наибольшее количество выручки было получено во вторник, далее следуют понедельник, четверг, среда, пятница, воскресенье, суббота как и до удаления.
#
# В 4 квартале 2018 г. наибольшее количество выручки приходилось также на вторник, понедельник и четверг, далее следует пятница, среда, на последнем месте также находятся воскресенье и суббота.
#
# В январе 2020 г. наибольшее количество выручки было получено в среду, четверг, воскресенье, пятницу, субботу, вторник и понедельник.
#
# При анализе количества пользователей интернет-магазина по дням недели было обнаружено следующее:
#
# 1) в 2019 г.: максимальное количество клиентов зафиксировано в понедельник, вторник, четверг и среду, а минимальное - пятницу, воскресенье и субботу.
#
# 2) в 2018 г.: максимальное количество клиентов зафиксировано понедельник, вторник, среду и пятницу, наименьшее количество - в воскресенье и субботу.
#
# 3) в 2020 г.: максимальное количество пользователей приходится на среду, четверг, воскресенье; в пятницу и субботу количество пользователей одинаковое; наименьшее количество - во вторник и понедельник.
#
# Далее определим, в какое время пользователи чаще всего совершали покупки в интернет-магазине.

# %%
revenue_by_time = data.groupby(['time'])['revenue'].sum().reset_index().sort_values(by = 'revenue', ascending=False).round(2)
revenue_by_time #определим выручку по времени суток
# Out:
#         time    revenue
# 13  13:00:00  335848.33
# 11  11:00:00  316421.00
# 12  12:00:00  287143.67
# 15  15:00:00  269934.17
# 17  17:00:00  264180.00
# 10  10:00:00  263134.17
# 14  14:00:00  253835.50
# 16  16:00:00  253704.50
# 9   09:00:00  239727.00
# 18  18:00:00  195455.75
# 8   08:00:00  184050.50
# 19  19:00:00  175562.00
# 21  21:00:00  174267.67
# 7   07:00:00  153638.00
# 20  20:00:00  145337.00
# 22  22:00:00  136076.33
# 23  23:00:00   77841.50
# 6   06:00:00   54954.00
# 0   00:00:00   46913.50
# 2   02:00:00   28474.00
# 1   01:00:00   27310.00
# 5   05:00:00   23374.50
# 4   04:00:00   21680.33
# 3   03:00:00   11251.00

# %%
customers_by_time = data.groupby(['time'])['customer_id'].nunique().reset_index().sort_values(by = 'customer_id', ascending=False).round(2)
customers_by_time #определим количество клиентов по времени суток
# Out:
#         time  customer_id
# 11  11:00:00          251
# 12  12:00:00          246
# 10  10:00:00          244
# 14  14:00:00          239
# 13  13:00:00          237
# 15  15:00:00          224
# 16  16:00:00          200
# 9   09:00:00          190
# 17  17:00:00          176
# 21  21:00:00          172
# 19  19:00:00          156
# 18  18:00:00          154
# 20  20:00:00          149
# 22  22:00:00          137
# 8   08:00:00          131
# 23  23:00:00          107
# 7   07:00:00           76
# 0   00:00:00           55
# 6   06:00:00           38
# 1   01:00:00           33
# 2   02:00:00           25
# 5   05:00:00           22
# 4   04:00:00           21
# 3   03:00:00           11

# %%
#построим график с отображением суммарной выручки по времени суток
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = revenue_by_time, x='time', y='revenue').set_title('Выручка интернет-магазина по времени суток');
plt.xlabel("Период получения выручки, время суток");
plt.ylabel("Объем выручки, млн. руб.");

#построим график с отображением суммарного количества клиентов по времени суток
sns.set_style('whitegrid');
plt.figure(figsize=(30, 15));
ax = sns.barplot(data = customers_by_time, x='time', y='customer_id').set_title('Количество пользователей интернет-магазина по времени суток');
plt.xlabel("Период, время суток");
plt.ylabel("Количество пользователей");

# %% [markdown]
# После удаления аномалии, видно, что наибольшее количество полученной выручки приходятся на 13:00, 11:00, 12:00, 15:00.
# В 17:00 и 10:00 показатель выручки находится приблизительно на одном уровне, далее идут временные промежутки 14:00, 16:00, 09:00 и 18:00. Наименьшая выручка приходится на ночное время - 02:00, 01:00, 05:00, 04:00 и на 03:00.
#
# При анализе количества пользователей выявлено следующее:
#
# 1) Наибольшее количество пользователей - 11:00, 12:00, 10:00, 14:00, 13:00;
#
# 2) Количество пользователей в 19:00, 18:00 приблизительно одинаковое;
#
# 3) Наименьшее количество пользователей - 05:00, 04:00, 02:00, 03:00.
#
# Далее необходимо изучить ассортимент товаров интернет-магазина и сгруппировать их по категориям.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
# <div class="alert alert-success">
# <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# Повторюсь, но сама исследовательская часть мне нравится)
# </p>
#     </div>

# %%
data[['product']].sample(5553)
# Out:
#                                                 product
# 7304  скатерть dasch донна роза из пвх 0401-2 розы к...
# 744         кружка для чая ягода клубника 250 мл 1606-д
# 3294  петуния surfinia crazy pink розовая с прожилко...
# 3705           петуния гибридная ампельная, диам. 21 см
# 3438  петуния sweetunia rose gem розовая с прожилкам...
# ...                                                 ...
# 4094  пеларгония зональная диам. 12 см красный махровый
# 215                       азалия индика биколор d-12 см
# 5554  петуния potunia plus purple бургунди с прожилк...
# 5660    ванна 70 л оцинкованная г.магнитогорск, 1301016
# 7347                             тимьян крымский d-7 см
#
# [5553 rows x 1 columns]

# %%
unique_products = data['product'].unique().tolist()
unique_products
# Out:
# ['комнатное растение в горшке алое вера, d12, h30',
#  'комнатное растение в горшке кофе арабика, d12, h25',
#  'радермахера d-12 см h-20 см',
#  'хризолидокарпус лутесценс d-9 см',
#  'циперус зумула d-12 см h-25 см',
#  'шеффлера лузеана d-9 см',
#  'юкка нитчатая d-12 см h-25-35 см',
#  'настенная сушилка для белья gimi brio super 100',
#  'таз пластмассовый 21,0 л круглый "водолей" с614, 1404056',
#  'чехол для гладильной доски colombo persia beige 130х50 см из хлопка 5379',
#  'вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, attribute, ahs331',
#  'сушилка для белья потолочная zalger lift basic 1520 200 см, 10 м',
#  'чехол eurogold clean basic хлопок для досок 120х38-120х42 см c42',
#  'крючок одежный 2-х рожковый серый металлик с полимерным покрытием *тонар*, 1110027',
#  'корзина мягкая пластиковая 17 л, м-пластика, m2880',
#  'чехол для гладильной доски festival 137x60 см из хлопка 4738',
#  'сумка-тележка 2-х колесная gimi argo синяя',
# ...

# %%
#импорт библиотеки для лемматизации
from pymystem3 import Mystem
m = Mystem()

#сохраняем уникальные значения
purpose_word = data['product'].unique() 

#объединим значения целей в единую строку
purpose_string = ' '.join(purpose_word)

#Применим лемматизацию
lemmas = m.lemmatize(purpose_string)

# %%
#Выведем количество часто встречающихся слов
from collections import Counter
print(Counter(lemmas))
# Out:
# Counter({' ': 17700, ', ': 1066, 'см': 1060, '-': 976, 'для': 547, ',': 295, 'в': 274, 'd': 260, 'л': 253, 'с': 253, 'рассада': 221, '5': 190, ' (': 173, 'белый': 172, 'сорт': 171, 'кассета': 170, 'шт': 169, '0': 164, '12': 147, 'белье': 144, 'красный': 143, ') ': 142, 'доска': 132, '/': 132, 'горшок': 130, '9': 123, 'сушилка': 120, 'цветок': 118, 'объем': 114, 'гладильный': 113, '2': 113, '6': 110, 'тележка': 108, '1': 108, 'по': 101, '4': 101, 'томат': 100, '10': 99, 'сумка': 98, '. ': 98, 'диам': 95, 'помидор': 93, '*': 90, '№': 88, 'пеларгония': 86, 'розовый': 84, 'из': 82, '3': 82, 'и': 81, 'luminarc': 79, 'хозяйственный': 77, 'gimi': 75, '7': 75, 'ника': 75, 'среднеспелый': 73, '20': 72, 'коврик': 72, 'ванный': 72, 'кухня': 71, 'зелень': 68, 'муляж': 68, 'роза': 68, 'черный': 67, 'мл': 67, 'синий': 63, 'махровый': 62, 'м': 61, 'г': 61, 'зональный': 61, 'искусственный': 61, 'h': 60, 'чехол': 60, 'attribute': 60, 'пластмассовый': 59, '100': 58, 'однолетний': 57, 'пластиковый': 54
# ...

# %%
# составление словаря
category_dict = {'растения и цветы': ['комнатное', 'радермахера', 'хризолидокарпус', 'циперус', 'мединилла', 'шеффлера', 'юкка', 'многолетнее',
        'рассада', 'герань', 'пеларгония', 'суккулент', 'эхеверия', 'эвкалипт', 'цветок', 'адиантум', 'кампанула', 'калатея', 'нолина',
        'хлорофитум', 'цикламен', 'глоксиния', 'азалия', 'гортензия', 'хризантема', 'мирт', 'цветущее', 'кориандр', 'иссоп', 'сантолина',
        'аспарагус', 'афеляндра', 'антуриум', 'молодило', 'фиалка', 'гербера', 'душица', 'мелисса', 'роза', 'бегония', 'альбука',
        'бальзамин', 'крассула', 'артемизия', 'лаванда', 'каланхое', 'примула', 'дендробиум', 'калоцефалус', 'каллуна', 'капсикум',
        'мимоза', 'соланум', 'бархатцы', 'космея', 'настурция', 'петуния', 'алиссум', 'гвоздика', 'годеция', 'календула',
        'кореопсис', 'лапчатка', 'львиный', 'флокс', 'цинерария', 'эшшольция', 'диффенбахия', 'фаленопсис', 'пуансетия',
        'гиностемма', 'ель', 'кипарисовик', 'аптения', 'новогоднее', 'пуансеттия', 'скиммия', 'фиттония', 'алоэ', 'спатифиллум',
        'фикус', 'кодонанта', 'цикламен,', 'гимнокалициум', 'эхинокактус', 'фал', 'крокусы', 'гипсофила', 'калибрахоа', 'эпипремнум',
        'аквилегия', 'незабудка', 'седум', 'нефролепис', 'калла', 'декабрист', 'тюльпан', 'гиацинт', 'вербена', 'однолетнее', 'чабер', 'бакопа', 'ранункулус', 'газания', 'овсянница', 'георгина', 'смолевка', 'цинния', 
        'вербейник', 'виола', 'колокольчик', 'котовник', 'эхинацея', 'ясколка', 'лилейник', 'папоротник', 'платикодон', 'энотера', 'фуксия',
        'цитрофортунелла', 'пеперомия', 'циния', 'синнингия', 'гардения', 'лобелия', 'табак', 'девичий', 'мускари', 'пиретрум',
        'агератум', 'колеус', 'тагетис', 'цинерания', 'муррайя', 'портулак', 'астра', 'аргирантерум', 'левкой', 'вероника', 'целозия',
        'маттиола', 'сальвия', 'джункус', 'драцена', 'фатсия', 'хоста', 'гайлардия', 'монарда', 'нивянник', 'рудбекия', 'барвинок', 'осина', 'сциндапсус', 'пряные', 'бузульник', 'камнеломка', 'солидаго', 'физостегия',
        'бадан', 'лен', 'лантана', 'лаватера', 'анемона', 'буддлея', 'валериана', 'змееголовник', 'любисток', 'шалфей', 'вигна', 'хамедорея', 'зверобой', 'импатиенс', 'клен', 'замиокулькас', 'амариллис', 'пахира', 'литопс'],
 'хозяйственные товары': ['настенная', 'таз', 'чехол', 'вешалка', 'сушилка', 'крючок', 'корзина', 'доска', 'набор', 'подкладка', 'гладильная', 'стяжка', 'комплект', 'плечики',
     'крепеж', 'пружина', 'петля', 'щетка-утюжок', 'подрукавник', 'сверло-фреза,', 'насадка', 'ножеточка', 'вешалка-плечики', 'настольная', 'холодная', 'шнур',
     'урна', 'сметка', 'измерительный', 'линейка,', 'бензин', 'петля-стрела', 'вешалка-стойка', 'держатель', 'пробка', 'вешалки', 'ролик', 'сменный', 'термометр', 'шило', 'кухонные',
     'рассекатель', 'сетка', 'вешалка-сушилка', 'ручка-скоба', 'многофункциональный', 'кольца',  'защитная', 'вешалка-перекладина',
     'насадка-отжим', 'штанга', 'штангенциркуль', 'рукав', 'бак', 'подвесное', 'автоматическая', 'тряпкодержатель', 'бельевые', 'сверло', 'фиксатор-шар', 'отжим', 'шпагат',
     'прищепки', 'покрытие', 'веревка', 'мешок', 'ручка', 'пьезозажигалка', 'решетка', 'запасная', 'уголок', 'вакуумный',  'основание', 'стяжки', 'шпингалет'],
 'посуда': ['мини-сковорода', 'сковорода', 'стеклянная', 'тарелка', 'котел', 'дозатор', 'кувшин', 
    'банка', 'противень', 'вкладыши', 'tepмокружка', 'контейнер', 'ведро', 'масленка', 'корыто', 'салатник', 'чайный', 'терка', 'кружка', 'салфетница', 'стакан', 'столовая', 'лоток', 'ковш', 
     'жестяная', 'миска', 'термостакан', 'защитный', 'термокружка', 'термос', 'фарфоровая', 'столовый',
    'блюдце', 'бульонница', 'разделочная', 'емкость', 'модульная', 'просеиватель', 'кастрюля', 'хлебница', 'форма', 
    'сито', 'тортница', 'блюдо', 'сотейник', 'бидон', 'ваза', 'отделитель', 'крышка', 'сахарница',
    'универсальный', 'мерный', 'мантоварка', 'мантоварка-пароварка', 'овощеварка'],
 'сумки и тележки': ['сумка-тележка', 'сумка', 'тележка'],
 'интерьер и декор': ['коврик',  'ковер', 'готовая', 'искусственный', 'штора', 'декоративная', 'салфетка', 'ковёр', 'карниз', 'подголовник', 'сиденье',
        'сервировочная', 'комод', 'подставка', 'фоторамка', 'этажерка', 'полки', 'ключница', 'нетканые', 'подарочный', 'полка', 'урна-пепельница',
        'ткань', 'обувница-3', 'стеллаж', 'складной', 'завертка'],
 'электрические товары': ['чайник', 'миксер', 'светильник', 'утюг', 'измельчитель', 'фен', 'весы', 'электроштопор', 'пылесос', 'соковарка', 'соковыжималка', 'кипятильник'], 
 'домашний текстиль': ['халат', 'полотенце', 'наматрасник', 'наматрицник-чехол', 'покрывало', 'подушка', 'одеяло', 'наматрацник', 'наволочка', 'пододеяльник', 'двуспальное', 
          'скатерть', 'плед', 'простыня', 'простынь', 'махровое', 'кухонное', 'махровый'], 'организация хранения':['кофр', 'ящик', 'короб', 'коробка', 'складная', 'корзинка'],
 'гигиена':['мыльница', 'увлажняющая','гипоаллергенный', 'зубная', 'мыло', 'мыло-скраб', 'жидкое', 'пена', 'паста', 'универсальное', 'ароматизированное', 'бальзам'], 
 'семена':['кабачок', 'тыква', 'арбуз', 'баклажан', 'клубника', 'патиссон', 'базилик', 'горох', 'земляника', 'капуста', 'мята', 'морковь', 'розмарин', 'огурец', 'кофе', 'томата', 'тимьян', 'петрушка', 'сельдерей', 'дыня', 'подсолнечник', 'салат', 'лавр', 'томат', 'укроп', 'лук'], 
 'товары для уборки':['щётка', 'губка', 'веник', 'швабра', 'щетка', 'ёрш', 'мусорный', 'перчатки', 'щетка-сметка', 'ерш', 'вантуз', 'совок', 'окномойка', 'сменная', 'насадка-моп', 'тряпка'],
 'бытовая химия':['антинакипин', 'кондиционер', 'ополаскиватель', 'отбеливатель', 'ванна', 'концентрат', 'стиральный', 'чистящий', 'антижир', 'средство'], 
 'столовые приборы и принадлежности':['вилка', 'ложка', 'нож', 'толкушка', 'чайная', 'лопатка', 'скалка', 'венчик', 'орехоколка', 'половник', 'овощечистка', 'кисточка', 'скребок', 'картофелемялка', 'шприц', 'пресс', 'рыбочистка'], 
 'муляжи':['муляж', 'искусственная'], 'лестницы и стремянки':['стремянка', 'лестница-стремянка', 'стремянки', 'стремянка-табурет', 'лестница']}

# %%
# создаем функцию, которая првоеряет в столбце значение из списка, при нахождении значения записывает в столбце категория
def category_func(name):
    for key, value in category_dict.items():
        for word in value:
            if name.find(word) > -1:
                return key
    return 'Нет категории'

data['category'] = data['product'].apply(category_func)

# %%
data.groupby('category').agg({'customer_id':'nunique',
                                  'quantity':'sum', 
                                  'order_id':'count',
                                  'product':'nunique',
                                  'price':'mean',
                                  'revenue':'sum'}).reset_index().round(2)
# Out:
#                              category  customer_id  quantity  order_id  \
# 0                       бытовая химия           15        15        15
# 1                             гигиена           21        51        24
# 2                   домашний текстиль           48        96        50
# 3                    интерьер и декор          258       659       303
# 4                лестницы и стремянки           42        46        45
# 5                              муляжи           91      1256       145
# 6                организация хранения           18        41        18
# 7                              посуда          252      1046       305
# 8                    растения и цветы         1274      5424      3086
# 9                              семена          128       550       329
# 10  столовые приборы и принадлежности           35        91        43
# 11                    сумки и тележки          323       433       369
# ...

# %% [markdown]
# Таким образом, было выделено 15 категорий товаров в интернет-магазине:
#
# 1) бытовая химия;
#
# 2) гигиена;
#
# 3) домашний текстиль;
#
# 4) интерьер и декор;
#
# 5) лестницы и стремянки;
#
# 6) муляжи;
#
# 7) организация хранения;
#
# 8) посуда;
#
# 9) растения и цветы;
#
# 10) семена;
#
# 11) столовые приборы и принадлежности;
#
# 12) сумки и тележки;
#
# 13) товары для уборки;
#
# 14) хозяйственные товары;
#
# 15) электрические товары.
#
# Далее построим график выручки и количества покупателей по категориям товаров интернет-магазина.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# С самой категоризацией всё в порядке, но похоже, что замельчили с категориями. Есть смысл объединить некоторые, чтобы результат анализа категорий был менее случайным и более содержательным.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Я оставила категоризацию как есть.</div>

# %%
revenue_by_category = data.groupby(['category'])['revenue'].sum().reset_index().sort_values(by = 'revenue', ascending=False).round(2)
revenue_by_category #определим выручку по категориям товаров
# Out:
#                              category     revenue
# 8                    растения и цветы  1177144.83
# 13               хозяйственные товары   853160.50
# 11                    сумки и тележки   802431.25
# 3                    интерьер и декор   392147.50
# 7                              посуда   227144.00
# 4                лестницы и стремянки   110470.00
# 2                   домашний текстиль   104147.00
# 12                  товары для уборки    82685.50
# 5                              муляжи    66372.33
# 14               электрические товары    43618.00
# 9                              семена    26739.50
# 6                организация хранения    18689.00
# 10  столовые приборы и принадлежности    13918.00
# 0                       бытовая химия    11283.00
# 1                             гигиена    10164.00

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# На всякий случай напомню, что count не подходит для определения количества клиентов, т. к. считает строки, и это надо проверить везде по проекту, где нам не надо именно строки посчитать.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, заменила count на nunique.</div>

# %%
customers_by_category = data.groupby(['category'])['customer_id'].nunique().reset_index().sort_values(by = 'customer_id', ascending=False).round(2)
customers_by_category #определим количество клиентов по категориям товаров
# Out:
#                              category  customer_id
# 8                    растения и цветы         1274
# 13               хозяйственные товары          557
# 11                    сумки и тележки          323
# 3                    интерьер и декор          258
# 7                              посуда          252
# 9                              семена          128
# 5                              муляжи           91
# 12                  товары для уборки           62
# 2                   домашний текстиль           48
# 4                лестницы и стремянки           42
# 14               электрические товары           36
# 10  столовые приборы и принадлежности           35
# 1                             гигиена           21
# 6                организация хранения           18
# 0                       бытовая химия           15

# %%
#построим график с отображением суммарной выручки по категориям товаров
fig = px.bar(revenue_by_category,
             x='revenue',
             y='category',
             text = 'revenue',
             template='plotly_white', 
             color='category'
            )
# оформляем график
fig.update_layout(title='Выручка интернет-магазина по категориям товара',
                   xaxis_title='Объем выручки',
                   yaxis_title='Категория',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=False)
fig.show()

#построим график с отображением суммарного количества клиентов по категориям товаров
fig = px.bar(customers_by_category,
             x='category',
             y='customer_id',
             text = 'customer_id',
             template='plotly_white', 
             color='category'
            )
# оформляем график
fig.update_layout(title='Количество клиентов интернет-магазина в каждой категории',
                   xaxis_title='Категория',
                   yaxis_title='Количество клиентов',
                   yaxis={'categoryorder':'total ascending'},
                   showlegend=False)
fig.show()
# Out:
# <div>                            <div id="8a756c4f-3ee0-4e0d-aace-8897a31b6d3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a756c4f-3ee0-4e0d-aace-8897a31b6d3b")) {                    Plotly.newPlot(                        "8a756c4f-3ee0-4e0d-aace-8897a31b6d3b",                        [{"alignmentgroup":"True","hovertemplate":"category=%{y}<br>revenue=%{text}<extra></extra>","legendgroup":"\u0440\u0430\u0441\u0442\u0435\u043d\u0438\u044f \u0438 \u0446\u0432\u0435\u0442\u044b","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0440\u0430\u0441\u0442\u0435\u043d\u0438\u044f \u0438 \u0446\u0432\u0435\u0442\u044b","offsetgroup":"\u0440\u0430\u0441\u0442\u0435\u043d\u0438\u044f \u0438 \u0446\u0432\u0435\u0442\u044b","orientation":"h","sho
# ...

# %% [markdown]
# Таким образом, видно, что наибольшая выручка была получена по категории "Растения и цветы", на втором месте - "Хозяйственные товары", на третьем - "Сумки и тележки". Наименьший объем выручки был получен по категориям "Хранение и порядок" и "Бытовая химия" и "Гигиена".
#
# Наибольшее количество клиентов совершили заказы в категории "Растения и цветы", "Хозяйственные товары". Далее следуют категории "Сумки и тележки", "Интерьер и декор", " Посуда" и "Семена". Наименьшее количество клиентов совершили заказы в категориях "Столовые приборы и принадлежности", "Гигиена", "Организация хранения", "Бытовая химия".
#
#
# ## Сегментация пользователей на основе истории их покупок
#
# Далее проведем сегментацию пользователей на основании истории их покупок.
#
# Сегментация будет проведена следующим образом:
#
# 1) сегментация пользователей по категориям совершенных покупок;
#
# 2) сегментация пользователей по среднему чеку и выручке;
#
# 3) сегментация пользователей по периоду совершения покупки: месяц, время года, день недели, время суток.
#
#
#
# Проведем сегментацию пользователей по категориям совершенных покупок:

# %%
data['test_column'] = 1
classification = data.pivot_table(index = 'customer_id', columns = 'category', values='test_column', aggfunc='mean')
classification = classification.reset_index()
classification = classification.fillna(0)
classification
X = classification.drop(['customer_id'], axis = 1)
scaler = StandardScaler()
X_st = scaler.fit_transform(X)
linked = linkage(X_st, method='ward')
plt.figure(figsize=(25, 10))
dendrogram(linked, orientation='top')
plt.title('\n Иерархическая кластеризация', fontsize=15)
plt.show()
km = KMeans(n_clusters = 15, random_state = 0)
labels = km.fit_predict(X_st)
classification['cluster_km'] = labels

# %%
plt.figure(figsize=(13,10))
plt.title('Процент покупателей в кластерах с товарами различных категорий', fontsize = 15)
sns.heatmap(classification.groupby('cluster_km').mean().T.loc[:'электрические товары'], annot=True, cmap='coolwarm', square=False, fmt='.1%')
plt.show()
#присвоим каждому кластеру основную категорию товаров
cluster_to_category = pd.DataFrame()
categories_list = ['растения и цветы','хозяйственные товары','сумки и тележки','семена','посуда','интерьер и декор','муляжи','товары для уборки','домашний текстиль',
                   'лестницы и стремянки','электрические товары','столовые приборы и принадлежности','гигиена','организация хранения','бытовая химия']
for i, category in zip(range(0,15), categories_list):
  cluster_to_category.loc[i, 'category'] = category
cluster_to_category = cluster_to_category.reset_index()
cluster_to_category.columns = ['cluster_km', 'category']

# %% [markdown]
# В результате было получено 15 кластеров, каждому кластеру соответствует одна категория товаров, купленная каждым покупателем из кластера. По тепловой карте видно, что сразу несколько категорий товаров приобретаются одними и теми же клиентами:
#
# 1) покупатели из раздела "Интерьер и декор" в 29,6% покупают товары из категории "Растения и цветы", в 3,5% - тележки, в 11,1% - хозяйственные товары;
#
# 2) покупатели из раздела "Муляжи" в 2,3% покупают предметы из раздела "Интерьер и декор", в 1,1% - посуду, в 23% - растения и цветы, в 3,4% - семена, в 4,6% - сумки и тележки, в 5,7% - хозяйственные товары;
#
# 3) покупатели из раздела "Хозяйственные товары" в 29,4% покупают предметы из раздела "Растения и цветы";
#
# 4) покупатели из раздела "Посуда" в 3,5% покупают товары из "Интерьер и декор", в 19,8% - растения и цветы, в 6,2% - сумки и тележки, в 8,8% - хозяйственный товары;
#
# 5) покупатели из раздела "Домашний текстиль" в 7% покупают товары из "Интерьер и декор", в 4,7% - посуда, в 30,2% - растения и цветы, в 2,3% - сумки и тележки, в 2,3% - товары для уборки,в 11,6% - хозяйственный товары;
#
# 6) покупатели из раздела "Сумки и тележки" в 27% покупают товары из "Растения и цветы", в 7,9% - хозяйственный товары;
#
# 7) покупатели из раздела "Лестницы и стремянки" в 10,8% покупают товары из "Посуда", в 24,3% - растения и цветы, в 2,7% - семена, в 2,7% - товары для уборки,в 8,1% - хозяйственный товары;
#
# 8) покупатели из раздела "Гигиена" в 10,5% покупают товары из "Интерьер и декор", в 5,3% - муляжи, в 10,5% - посуда, в 15,8% - растения и цветы, в 5,3% - столовые приборы и принадлежности, в 5,3% - сумки и тележки, в 21,1% - хозяйственный товары;
#
# 9) покупатели из раздела "Товары для уборки" в 3,6% покупают товары из "Интерьер и декор", в 1,8% - посуда, в 25% - растения и цветы, в 3,6% - семена, в 5,4% - сумки и тележки, в 17,9% - хозяйственный товары;
#
# 10) покупатели из раздела "Семена" в 4,2% покупают товары из "Интерьер и декор", в 1,7% - посуда, в 49,2% - растения и цветы, в 5,9% - сумки и тележки, в 13,6% - хозяйственный товары;
#
# 11) покупатели из раздела "Электрические товары" в 3% покупают товары из "Домашний текстиль", в 6,1% - интерьер и декор ,в 3% - лестницы и стремянки и муляжи, в 12,1% - посуда, в 21,2% - растения и цветы, в 6,1% - семена, в 9,1% - сумки и тележки, в 24,2% - хозяйственный товары;
#
# 12) покупатели из раздела "Организация хранения" в 11,8% покупают товары из "Интерьер и декор", в 5,9% - лестницы и стремянки, в 11,8% - посуда, в 17,6% - растения и цветы, в 5,9% - товары для уборки, в 5,9% - электрические товары, в 29,4% - хозяйственный товары;
#
# 13) покупатели из раздела "Бытовая химия" в 13,3% покупают товары из "Гигиена", "Домашний текстиль", "Интерьер и декор","Лестницы и стремянки", "Посуда", в 6,7% - организация хранения, в 46,7% - растения и цветы, в 6,7% - семена и столовые приборы и принадлежности, в 20% - сумки и тележки, в 26,7% - хозяйственный товары, в 6,7% - электрические товары;
#
# 14) покупатели из раздела "Столовые приборы и принадлежности" в 6,1% покупают товары из "Домашний текстиль", в 12,1% - "Интерьер и декор", в 3% - "Лестницы и стремянки", в 6,1% - муляжи, в 15,2% - "Посуда", в 27,3% - растения и цветы, в 3% - семена и сумки и тележки и электрические товары, в 9,1% - товары для уборки, в 33,3% - хозяйственный товары;
#
# 15) покупатели из категории "Растения и цветы" не покупают товары из других категорий.
#
# Далее проведем сегментацию пользователей по среднему чеку и выручке в разрезе кластеров и сезонов.

# %%
revenue_per_category_season = data.pivot_table(
    index='category', columns=['season'], values='revenue', aggfunc='sum')
plt.figure(figsize=(15, 15))
sns.heatmap(revenue_per_category_season, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Суммарная выручка с категории товара в разрезе по кластерам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Напомню, что для расчета среднего чека надо или посчитать стоимость каждого заказа в отдельности и взять среднее, или посчитать суммарную выручку и разделить её на количество уникальных заказов. Ниже там то же самое.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, поправила формулу расчета.</div>

# %%
avg_revenue_per_category_season = data.pivot_table(
    index='category', columns=['season'], values='revenue', aggfunc='sum')/data.pivot_table(
    index='category', columns=['season'], values='order_id', aggfunc='nunique')

plt.figure(figsize=(15, 15))
sns.heatmap(avg_revenue_per_category_season, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Средняя выручка с категории товара в разрезе по кластерам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Далее проведем сегментацию пользователей по среднему чеку и выручке в разрезе кластеров и месяцев.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь стоит внизу упорядочить месяцы, чтобы можно было читать график.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, месяцы упорядочены.</div>

# %%
revenue_per_category_month = data.pivot_table(
    index='category', columns=['month'], values='revenue', aggfunc='sum')
plt.figure(figsize=(15, 15))
sns.heatmap(revenue_per_category_month, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Суммарная выручка с категории товара в разрезе по кластерам и месяцам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
avg_revenue_per_category_month = data.pivot_table(
    index='category', columns=['month'], values='revenue', aggfunc='sum')/data.pivot_table(
    index='category', columns=['month'], values='order_id', aggfunc='nunique')
plt.figure(figsize=(15, 15))
sns.heatmap(avg_revenue_per_category_month, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Средняя выручка с категории товара в разрезе по кластерам и месяцам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Далее проведем сегментацию пользователей по среднему чеку и выручке в разрезе кластеров и дней недели.

# %%
revenue_per_category_weekday = data.pivot_table(
    index='category', columns=['weekday'], values='revenue', aggfunc='sum')
plt.figure(figsize=(15, 15))
sns.heatmap(revenue_per_category_weekday, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Суммарная выручка с категории товара в разрезе по кластерам и дням недели')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
avg_revenue_per_category_weekday = data.pivot_table(
    index='category', columns=['weekday'], values='revenue', aggfunc='sum')/data.pivot_table(
    index='category', columns=['weekday'], values='order_id', aggfunc='nunique')
plt.figure(figsize=(15, 15))
sns.heatmap(avg_revenue_per_category_weekday, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Средняя выручка с категории товара в разрезе по кластерам и дням недели')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Далее проведем сегментацию пользователей по среднему чеку и выручке в разрезе кластеров и времени суток.

# %%
revenue_per_category_time = data.pivot_table(
    index='category', columns=['time'], values='revenue', aggfunc='sum')
plt.figure(figsize=(30, 20))
sns.heatmap(revenue_per_category_time, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Суммарная выручка с категории товара в разрезе по кластерам и времени суток')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
avg_revenue_per_category_time = data.pivot_table(
    index='category', columns=['time'], values='revenue', aggfunc='sum')/data.pivot_table(
    index='category', columns=['time'], values='order_id', aggfunc='nunique')
plt.figure(figsize=(30, 20))
sns.heatmap(avg_revenue_per_category_time, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Средняя выручка с категории товара в разрезе по кластерам и времени суток')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Екатерина, давай немного терминологию поправим.
#
# Сегментация покупателей предполагает разделение их на конкретные группы. Там выше, где мы по категориям товаров пользователей поделили при помощи кластеризации - это сегментация. Ниже, где мы хитмэпы смотрели - это анализ, но не сегментация. В принципе, для целей проекта сегментации по категориям достаточно.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Спасибо за объяснение, я оставлю только сегментацию покупателей по категориям товаров.</div>

# %% [markdown]
# Как видно из хитмэпов, у товаров интернет-магазина присутствует сезонность в зависимости от времени года, месяца, дня недели и времени суток.
#
# В зависимости от времени года меняются приоритеты пользователей и объем полученной выручки и средний чек товаров по категориям:
#
# 1) вне зависимости от времени года наиболее прибыльными являются четыре категории товаров: растения и цветы, хозяйственные товары, сумки и тележки, интерьер и декор, а наименее прибыльными - бытовая химия, гигиена, организация хранения, семена, столовые приборы и принадлежности;
#
# 2) При анализе суммарной выручки с категории товара по кластерам и сезонам следующее:
#
# - наибольший спрос на категорию "Растения и цветы" зимой и весной, осенью и летом спрос на товары из категории снижается;
#
# - наибольший спрос на категорию "Сумки и тележки" зимой и осенью, снижается весной и летом;
#
# - наибольший спрос на категорию "Хозяйственные товары" осенью и зимой, снижается летом и весной;
#
# - наибольший спрос на категорию "Интерьер и декор" зимой и осенью, снижается весной и летом;
#
# - и т. д.;
#
# 3) При анализе среднего чека с категории товара по кластерам и сезонам следующее:
#
# - наибольший средний чек у товаров категории "Домашний текстиль", "Лестницы и стремянки", "Сумки и тележки", "Интерьер и декор", "Хозяйственные товары";
#
# - у категории "Домашний текстиль" наибольший средний чек весной и летом, наименьший - осенью;
#
# - у категории "Лестницы и стремянки" наибольший средний чек летом и осенью, наименьший - весной;
#
# - у категории "Сумки и тележки" наибольший средний чек зимой и весной, наименьший - летом;
#
# - у категории "Интерьер и декор" наибольший средний чек зимой и летом, наименьший - осенью;
#
# - у категории "Хозяйственные товары" наибольший средний чек летом и весной, наименьший - осенью;
#
# - и т. д.;
#
# 4) При анализе суммарной выручки с категории товара по кластерам и месяцам следующее:
#
# - по месяцам ситуация аналогична сезонам - категории-лидеры те же;
#
# - наибольшая выручка по категории "Растения и цветы" в январе и октябре, наименьшая - в августе и сентябре;
#
# - наибольшая выручка по категории "Сумки и тележки" в декабре и ноябре, наименьшая - в июле и июне;
#
# - наибольшая выручка по категории "Хозяйственные товары" в ноябре, декабре и октябре, наименьшая - в августе и сентябре;
#
# - наибольшая выручка по категории "Интерьер и декор" в декабре и октябре, наименьшая - в августе и июне;
#
# - и т. д.;
#
# - в некоторых месяцах отсутствовали продажи по некоторым категориям: в марте - бытовая химия; в апреле - гигиена и организация хранения; в мае - электрические товары, организация хранения, гигиена; в июне - бытовая химия и гигиена; в июле - гигиена; в августе - электрические товары, организация хранения, бытовая химия; в сентябре - организация хранения и гигиена.
#
#
# 5) При анализе среднего чека с категории товара по кластерам и месяцам следующее:
#
# - у категории "Домашний текстиль" наибольший средний чек в апреле и июне, наименьший - в мае и августе;
#
# - у категории "Лестницы и стремянки" наибольший средний чек в июне и августе, наименьший - в сентябре;
#
# - у категории "Сумки и тележки" наибольший средний чек в апреле, январе, феврале, наименьший - в сентябре и августе;
#
# - у категории "Интерьер и декор" наибольший средний чек в феврале и марте, наименьший - в январе и ноябре;
#
# - у категории "Хозяйственные товары" наибольший средний чек в июне и июле, наименьший - в октябре и сентябре;
#
# - и т. д.;
#
# - в некоторых месяцах отсутствовали продажи по некоторым категориям: в марте - бытовая химия; в апреле - гигиена и организация хранения; в мае - электрические товары, организация хранения, гигиена; в июне - бытовая химия и гигиена; в июле - гигиена; в августе - электрические товары, организация хранения, бытовая химия; в сентябре - организация хранения и гигиена.
#
# 6) При анализе суммарной выручки с категории товара по кластерам и дням недели следующее:
#
# - наибольшая выручка по категории "Растения и цветы" во вторник, понедельник и четверг, наименьшая - в субботу;
#
# - наибольшая выручка по категории "Сумки и тележки" в пятницу, среду и четверг, наименьшая - в субботу;
#
# - наибольшая выручка по категории "Хозяйственные товары" во вторник, понедельник и четверг, наименьшая - в воскресенье;
#
# - наибольшая выручка по категории "Интерьер и декор" в понедельник и среду, наименьшая - в пятницу;
#
# - и т. д.;
#
# - в субботу отсутствовали продажи по двум категориям: бытовая химия и электрические товары.
#
# 7) При анализе среднего чека с категории товара по кластерам и дням недели следующее:
#
# - у категории "Домашний текстиль" наибольший средний чек в пятницу и вторник, наименьший - в воскресенье;
#
# - у категории "Лестницы и стремянки" наибольший средний чек в понедельник и воскресенье, наименьший - во вторник;
#
# - у категории "Сумки и тележки" наибольший средний чек в пятницу и вторник, наименьший - в понедельник;
#
# - у категории "Интерьер и декор" наибольший средний чек в пятницу и субботу, наименьший - во вторник;
#
# - у категории "Хозяйственные товары" наибольший средний чек во вторник и четверг, наименьший - в субботу;
#
# - и т. д.;
#
# - в субботу отсутствовали продажи по двум категориям: бытовая химия и электрические товары.
#
# 8) При анализе суммарной выручки с категории товара по кластерам и времени суток следующее:
#
# - в 13:00, в 10:00 и 11:00 наибольшая выручка по всем категория товаров;
#
# - в ночное время по многим из категорий отстутсвуют продажи.
#
# 9) При анализе среднего чека с категории товара по кластерам и времени суток следующее:
#
# - максимальный средний чек по многим категориям приходится на дневное время;
#
# - в ночное время по многим из категорий отстутсвуют продажи.

# %% [markdown]
# ## Проверка статистических гипотез
#
# Далее проведем статистический анализ.
#
# Для целей исследования были выдвинуты две гипотезы, каждую из которых необходимо проверить.
#
# 1) Средний чек в будний день не отличается от среднего чека в выходной день:
#
# Нулевая гипотеза: средний чек в будний день равен среднему чеку в выходной день.
#
# Альтернативная гипотеза: средний чек в будний день отличается от среднего чека в выходной день.
#
# Коэффициент Alpha для целей исследования возьмем равный 0,05.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь надо поправить гипотезы. Судя по выборкам, мы сравниваем средний чек в будни и в выходные. И непонятно, почему мы считаем дисперсии одинаковыми. Давай передадим в критерий параметр equal_var=False.
#
# Еще давай выведем средние значения и количество измерений по группам, чтобы было понятно, что с чем мы сравниваем.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, поменяла equal_var на False и поправила гипотезы.</div>

# %%
cluster_working_day = data[data['weekday_type']=='working day'].groupby('order_id').agg({'revenue':'sum'})['revenue']
cluster_weekend = data[data['weekday_type']=='rest day'].groupby('order_id').agg({'revenue':'sum'})['revenue']

# %%
cluster_working_day.describe()
# Out:
# count     2740.000000
# mean      1169.643400
# std       2256.827301
# min          9.000000
# 25%        200.000000
# 50%        598.000000
# 75%       1312.000000
# max      49432.000000
# Name: revenue, dtype: float64

# %%
cluster_weekend.describe()
# Out:
# count     784.000000
# mean      937.871811
# std      1203.011416
# min        10.000000
# 25%       169.000000
# 50%       513.000000
# 75%      1162.000000
# max      8437.000000
# Name: revenue, dtype: float64

# %%
print('Дисперсия выручки cluster_working_day: {}'.format(np.var(cluster_working_day, ddof=1)))
print('Дисперсия выручки cluster_weekend: {}'.format(np.var(cluster_weekend, ddof=1)))
print('Соотношение дисперсий: {}'.format((np.var(cluster_weekend, ddof=1))/(np.var(cluster_working_day, ddof=1))))
# Out:
# Дисперсия выручки cluster_working_day: 5093269.466592163
# Дисперсия выручки cluster_weekend: 1447236.4660569394
# Соотношение дисперсий: 0.2841468482179612

# %%
alpha = 0.05 
results = st.ttest_ind(cluster_working_day, cluster_weekend, equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: между выборками есть значимая разница')
else:
    print('Не получилось отвергнуть нулевую гипотезу, нет оснований считать выборки разными')
# Out:
# p-значение:  0.0001436456023736327
# Отвергаем нулевую гипотезу: между выборками есть значимая разница

# %% [markdown]
# Таким образом, гипотеза о том, что средний чек в будний день равен среднему чеку в выходной день, отвергается, что также подтверждается результатами исследовательского анализа данных.

# %% [markdown]
# 2) Средний чек в дневное время не отличается от среднего чека в ночное время.
#
# Нулевая гипотеза: средний чек в дневное время равен среднему чеку в ночное время.
#
# Альтернативная гипотеза: средний чек в дневное время отличается от среднего чека в ночное время.
#
# Коэффициент Alpha для целей исследования возьмем равный 0,05.
#
# Для начала зададим функцию, которая определит день или ночь в зависимости от времени суток. Результат сохраним в колонку day_or_night.

# %%
#создадим колонку time_1 для сохранения часа из колонки time
data['time_1'] = data['date'].dt.hour

# %% [markdown]
# Для определения периода дня или ночи будем основываться на времени бодровствования людей:
#
# 1) день - промежуток времени с 07:00 до 21:00;
#
# 2) ночь - промежуток времени с 22:00 до 06:00.

# %%
def day_or_night(time): #зададим функцию для определения дня или ночи
    if  time == 7:
        return 'day'
    elif time == 8:
        return 'day'
    elif time == 9:
        return 'day'
    elif time == 10:
        return 'day'
    elif time == 11:
        return 'day'
    elif time == 12:
        return 'day'
    elif time == 13:
        return 'day'
    elif time == 14:
        return 'day'
    elif time == 15:
        return 'day'
    elif time == 16:
        return 'day'
    elif time == 17:
        return 'day'
    elif time == 18:
        return 'day'
    elif time == 19:
        return 'day'
    elif time == 20:
        return 'day'
    elif time == 21:
        return 'day'
    else:
        return "night"

# %%
#создадим колонку с определением типа дня или ночи для анализа и применим функцию выше для заполнения колонки
data['day_or_night'] = data['time_1'].apply(day_or_night) 

#выведим уникальные значения колонки для того, чтобы убедиться, что функция сработала
data['day_or_night'].unique()
# Out:
# array(['night', 'day'], dtype=object)

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь уже с гипотезами всё в порядке, но выборки надо поправить. Нам надо стоимость каждого заказа в них передать, т. е. в группировке вместо mean использовать sum.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, поменяла mean на sum.</div>

# %%
cluster_day = data[data['day_or_night']=='day'].groupby('order_id').agg({'revenue':'sum'})['revenue']
cluster_night = data[data['day_or_night']=='night'].groupby('order_id').agg({'revenue':'sum'})['revenue']

# %%
print('Дисперсия выручки cluster_day: {}'.format(np.var(cluster_day, ddof=1)))
print('Дисперсия выручки cluster_night: {}'.format(np.var(cluster_night, ddof=1)))
print('Соотношение дисперсий: {}'.format((np.var(cluster_night, ddof=1))/(np.var(cluster_day, ddof=1))))
# Out:
# Дисперсия выручки cluster_day: 4618101.769178001
# Дисперсия выручки cluster_night: 2014641.0246126805
# Соотношение дисперсий: 0.43624872844049006

# %%
alpha = 0.05 
results = st.ttest_ind(cluster_day, cluster_night, equal_var=True)
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: между выборками есть значимая разница')
else:
    print('Не получилось отвергнуть нулевую гипотезу, нет оснований считать выборки разными')
# Out:
# p-значение:  0.04766856283722472
# Отвергаем нулевую гипотезу: между выборками есть значимая разница

# %% [markdown]
# Таким образом, гипотеза о том, что cредний чек в дневное время не отличается от среднего чека в ночное время отвергается, что также подтверждается результатами исследовательского анализа данных, приведенного выше.

# %% [markdown]
# ## Выводы по проведенному исследованию
#
# Для целей данного исследования были предоставлены данные по продажам интернет-магазина за период с 01.10.2018 по 31.01.2020 гг.
#
# В результате исследования было выявлено следующее:
#
# 1) В датасете имелись скрытые дубликаты, существенно влияющие на расчет суммарной выручки магазина за заданный период, например, один и тот же заказ был сделан одним и тем же пользователем в одно и то же время, но в разные дни. Это может свидетельствовать о том, что формирование отчета о продажах может носить как ручной характер подготовки, так и говорить о технических проблемах работы самой системы учета магазина.
#
# Возможный путь решения проблем с задвоением данных о продажах: проследить, в какой именно момент формируются дубликаты и проверить как настройки формируемого отчета о продажах, так методику расчета, если данный отчет подготавливается преимущественно силами сострудника, а не выгружается из системы;
#
# 2) В ходе исследования были определены среднее количество уникальных клиентов за месяц (263 чел.), неделю (452 чел.) и день (6 чел.), средний чек заказа в размере 1622 руб., среднее количество заказов в день - 485 заказов, а также процент недельной и месячной аудитории - 1,54% и 2,64% соответственно.
#
# 3) Общее количество заказов магазина - 5553: 2019 г. - 4067, 2018 г. - 1217, 2020 г. - 269.
#
# Максимальное количество клиентов в зависимости от года и периода:
#
# - весна 2019 г. - 623 чел.;
#
# - осень 2019 г. - 565 чел.;
#
# - зима 2019 г. - 539 чел.
#
# Минимальное количество клиентов в зависимости от года и периода:
#
# - зима 2018 г. - 231 чел.;
#
# - зима 2020 г. - 269 чел.
#
# Максимальное количество клиентов приходилось на февраль, декабрь и апрель 2019 г.
#
# Минимальное количество клиентов - в январе, июне, августе и сентябре 2019 г.
#
# При анализе количества пользователей интернет-магазина по дням недели было обнаружено следующее:
#
# - в 2019 г.: максимальное количество клиентов зафиксировано в понедельник, вторник, четверг и среду, а минимальное - пятницу, воскресенье и субботу.
#
# - в 2018 г.: максимальное количество клиентов зафиксировано понедельник, вторник, пятницу; в среду и четверг количество пользователей было одинаковое; наименьшее количество - в воскресенье и субботу.
#
# - в 2020 г.: максимальное количество пользователей приходится на среду, четверг, воскресенье; в пятницу и субботу количество пользователей одинаковое; наименьшее количество - во вторник и понедельник.
#
# При анализе количества пользователей в зависимости от времени суток выявлено следующее:
#
# - Наибольшее количество пользователей - 11:00, 12:00, 10:00, 14:00, 13:00;
#
# - Количество пользователей в 19:00, 18:00 приблизительно одинаковое;
#
# - Наименьшее количество пользователей - 05:00, 04:00, 02:00, 03:00.
#
#
# 4) Количество уникальных пользователей магазина составило 2429 человек.
#
# В декабре и с февраля по апрель число уникальных покупателей наиболее высоко. В январские праздники спрос на продукцию магазина резко падает. То же самое происходит в июне. Вероятно, в середине дачного сезона уже не принято активно закупаться онлайн. Клиенты либо уже приобрели все необходимое, либо предпочтут офлайн магазин для более скорого результата. Тем не менее, в июле активность среди посетителей растет.
#
# 5) При анализе среднего чека было обнаружено следующее:
#
# - наибольший средний чек приходился на 2018 г., наименьший - на 2020 г.;
#
# - по времени года: наибольший средний чек приходится на летний, осенний и весенний сезоны, а наименьший - на зимний;
#
# - по месяцам: наибольший средний чек - в октябре, ноябре и декабре, наименьший средний чек - в августе и сентябре;
#
# - по дням недели: наибольший средний чек - во вторник, понедельник, четверг, далее следуют среда и четверг, наименьший - в субботу и воскресенье;
#
# - по времени суток: наибольший средний чек - в 07:00, 06:00, 17:00, 13:00 и 18:00, пиковое значение - 7:00, а наименьший чек - в 01:00, 00:00 и 23:00.
#
# 6) Общая выручка за исследуемый период составила 3 940 114,42 руб. Период получения наибольшей выручки - 2019 г., что неудивительно, т. к. за 2018 г. мы имеем данные за 4 квартал, а в 2020 г. - только за январь месяц.
#
# Максимальную выручку магазин получил:
#
# - весной, зимой 2019 г.: апреле, феврале и марте;
#
# - и осенью и зимой 2018 г.: ноябре, октябре и декабре.
#
# Минимальную выручку магазин получил:
#
# - летом и осенью 2019 г.: августе, сентябре и ноябре;
#
# - в январе 2020 г.
#
# По дням недели в зависимости от года дни максимальной выручки магазина приходятся на:
#
# - в 2018 г. - вторник, понедельник, четверг, пятница;
#
# - в 2019 г. - вторник, понедельник, четверг, среда;
#
# - в 2020 г. - среда, четверг, воскресенье, пятница.
#
# По дням недели в зависимости от года дни минимальной выручки магазина приходятся на:
#
# - в 2018 г. - пятница, воскресенье и суббота;
#
# - в 2019 г. - среда, воскресенье и суббота;
#
# - в 2020 г. - суббота, вторник и понедельник.
#
# Наибольшая выручка в зависимости от времени суток приходится на дневное время: 13:00, 11:00, 12:00, 15:00.
#
# Наименьшая выручка приходится на ночное время - 02:00, 01:00, 05:00, 04:00 и на 03:00.
#
# 7) Количество уникальных продуктов интернет-магазина - 2340, которые в ходе исследовательского анализа были распределены по 15 категориям: бытовая химия, гигиена, домашний текстиль, интерьер и декор, лестницы и стремянки, муляжи, организация хранения, посуда, растения и цветы, семена, столовые приборы и принадлежности, сумки и тележки, товары для уборки, хозяйственные товары, электрические товары.
#
# Наибольшая выручка по категориям товаров:
#
# - категория "Растения и цветы";
#
# - категория "Хозяйственные товары";
#
# - категория "Сумки и тележки".
#
# Наименьшая выручка по категориям товаров:
#
# - категория "Хранение и порядок";
#
# - категория "Бытовая химия";
#
# - категория "Гигиена".
#
# Наибольшее количество клиентов по категориям товаров:
#
# - категория "Растения и цветы";
#
# - категория "Хозяйственные товары";
#
# - категория "Сумки и тележки";
#
# - категория "Семена";
#
# - категория " Посуда";
#
# - категория "Интерьер и декор".
#
# Наименьшее количество клиентов по категориям товаров:
#
# - категория "Столовые приборы и принадлежности";
#
# - категория "Гигиена";
#
# - категория "Организация хранения";
#
# - категория "Бытовая химия".
#
# 8) В ходе исследования была проведена сегментация пользователей по категориям совершенных покупок, среднему чеку и выручке и по периоду совершения покупки. При сегментации выявлено следующее:
#
# - получены 15 кластеров, каждому из которых соответствует одна категория товаров, купленная каждым покупателем из кластера;
#
# - сразу несколько категорий товаров приобретаются одними и теми же клиентами;
#
# - чаще всего товары из других категорий приобретают клиенты, перешедшие из категорий "Столовые приборы и принадлежности", "Бытовая химия", "Организация хранения", "Электрические товары", "Муляжи" и "Гигиена".
#
# - реже всего товары из других категорий приобретаются клиентами из категорий "Хозяйственные товары", "Сумки и тележки", "Интерьер и декор".
#
# - покупатели из категории "Растения и цветы" не покупают товары из других категорий вообще.
#
# - у товаров интернет-магазина присутствует сезонность в зависимости от времени года, месяца, дня недели и времени суток.
#
# В зависимости от времени года меняются приоритеты пользователей и объем полученной выручки и средний чек товаров по категориям:
#
# 8.1) вне зависимости от времени года наиболее прибыльными являются четыре категории товаров: растения и цветы, хозяйственные товары, сумки и тележки, интерьер и декор, а наименее прибыльными - бытовая химия, гигиена, организация хранения, семена, столовые приборы и принадлежности;
#
#
# 8.2) При анализе суммарной выручки с категории товара по кластерам и сезонам следующее:
#
# - наибольший спрос на категорию "Растения и цветы" зимой и весной, осенью и летом спрос на товары из категории снижается;
#
# - наибольший спрос на категорию "Сумки и тележки" зимой и осенью, снижается весной и летом;
#
# - наибольший спрос на категорию "Хозяйственные товары" осенью и зимой, снижается летом и весной;
#
# - наибольший спрос на категорию "Интерьер и декор" зимой и осенью, снижается весной и летом;
#
# - и т. д.;
#
# 8.3) При анализе среднего чека с категории товара по кластерам и сезонам следующее:
#
# - наибольший средний чек у товаров категории "Домашний текстиль", "Лестницы и стремянки", "Сумки и тележки", "Интерьер и декор", "Хозяйственные товары";
#
# - у категории "Домашний текстиль" наибольший средний чек весной и летом, наименьший - осенью;
#
# - у категории "Лестницы и стремянки" наибольший средний чек летом и осенью, наименьший - весной;
#
# - у категории "Сумки и тележки" наибольший средний чек зимой и весной, наименьший - летом;
#
# - у категории "Интерьер и декор" наибольший средний чек зимой и летом, наименьший - осенью;
#
# - у категории "Хозяйственные товары" наибольший средний чек летом и весной, наименьший - осенью;
#
# - и т. д.;
#
# 8.4) При анализе суммарной выручки с категории товара по кластерам и месяцам следующее:
#
# - по месяцам ситуация аналогична сезонам - категории-лидеры те же;
#
# - наибольшая выручка по категории "Растения и цветы" в январе и октябре, наименьшая - в августе и сентябре;
#
# - наибольшая выручка по категории "Сумки и тележки" в декабре и ноябре, наименьшая - в июле и июне;
#
# - наибольшая выручка по категории "Хозяйственные товары" в ноябре, декабре и октябре, наименьшая - в августе и сентябре;
#
# - наибольшая выручка по категории "Интерьер и декор" в декабре и октябре, наименьшая - в августе и июне;
#
# - и т. д.;
#
# - в некоторых месяцах отсутствовали продажи по некоторым категориям: в марте - бытовая химия; в апреле - гигиена и организация хранения; в мае - электрические товары, организация хранения, гигиена; в июне - бытовая химия и гигиена; в июле - гигиена; в августе - электрические товары, организация хранения, бытовая химия; в сентябре - организация хранения и гигиена.
#
#
# 8.5) При анализе среднего чека с категории товара по кластерам и месяцам следующее:
#
# - у категории "Домашний текстиль" наибольший средний чек в апреле и июне, наименьший - в мае и августе;
#
# - у категории "Лестницы и стремянки" наибольший средний чек в июне и августе, наименьший - в сентябре;
#
# - у категории "Сумки и тележки" наибольший средний чек в апреле, январе, феврале, наименьший - в сентябре и августе;
#
# - у категории "Интерьер и декор" наибольший средний чек в феврале и марте, наименьший - в январе и ноябре;
#
# - у категории "Хозяйственные товары" наибольший средний чек в июне и июле, наименьший - в октябре и сентябре;
#
# - и т. д.;
#
# - в некоторых месяцах отсутствовали продажи по некоторым категориям: в марте - бытовая химия; в апреле - гигиена и организация хранения; в мае - электрические товары, организация хранения, гигиена; в июне - бытовая химия и гигиена; в июле - гигиена; в августе - электрические товары, организация хранения, бытовая химия; в сентябре - организация хранения и гигиена.
#
# 8.6) При анализе суммарной выручки с категории товара по кластерам и дням недели следующее:
#
# - наибольшая выручка по категории "Растения и цветы" во вторник, понедельник и четверг, наименьшая - в субботу;
#
# - наибольшая выручка по категории "Сумки и тележки" в пятницу, среду и четверг, наименьшая - в субботу;
#
# - наибольшая выручка по категории "Хозяйственные товары" во вторник, понедельник и четверг, наименьшая - в воскресенье;
#
# - наибольшая выручка по категории "Интерьер и декор" в понедельник и среду, наименьшая - в пятницу;
#
# - и т. д.;
#
# - в субботу отсутствовали продажи по двум категориям: бытовая химия и электрические товары.
#
# 8.7) При анализе среднего чека с категории товара по кластерам и дням недели следующее:
#
# - у категории "Домашний текстиль" наибольший средний чек в пятницу и вторник, наименьший - в воскресенье;
#
# - у категории "Лестницы и стремянки" наибольший средний чек в понедельник и воскресенье, наименьший - во вторник;
#
# - у категории "Сумки и тележки" наибольший средний чек в пятницу и вторник, наименьший - в понедельник;
#
# - у категории "Интерьер и декор" наибольший средний чек в пятницу и субботу, наименьший - во вторник;
#
# - у категории "Хозяйственные товары" наибольший средний чек во вторник и четверг, наименьший - в субботу;
#
# - и т. д.;
#
# - в субботу отсутствовали продажи по двум категориям: бытовая химия и электрические товары.
#
# 8.8) При анализе суммарной выручки с категории товара по кластерам и времени суток следующее:
#
# - в 13:00, в 10:00 и 11:00 наибольшая выручка по всем категория товаров;
#
# - в ночное время по многим из категорий отстутсвуют продажи.
#
# 8.9) При анализе среднего чека с категории товара по кластерам и времени суток следующее:
#
# - максимальный средний чек по многим категориям приходится на дневное время;
#
# - в ночное время по многим из категорий отстутсвуют продажи.
#
#
# 9) В ходе исследования был проведен статистический анализ, в рамках которого были проверены две гипотезы:
#
# - Гипотеза 1 - "Средний чек в будний день не отличается от среднего чека в выходной день" (нулевая гипотеза: средний чек в будний день равен среднему чеку в выходной день; альтернативная – средний чек в будний день отличается от среднего чека в выходной день);
#
# - Гипотеза 2 - "Средний чек в дневное время не отличается от среднего чека в ночное время" (нулевая гипотеза: средний чек в дневное время равен среднему чеку в ночное время; альтернативная - средний чек в дневное время отличается от среднего чека в ночное время).
#
# Обе теории гипотезы были отвергнуты - в ходе исследования было доказано, что средний чек в будний день превышает средний чек в выходной день, а также что средний чек в дневное время выше среднего чека в ночное время.
#
#
# ## Описание существующих проблем интернет-магазина и подготовка рекомендации по их устранению
#
# Таким образом, по результатам проведенного исследования можно выявить следующие ключевые проблемы интернет-магазина:
#
# 1) За 2019 г. снизились показатели среднего чека и прибыльности интернет-магазина, а также количество пользователей.
#
# 2) В магазине присутствует выраженная сезонность товаров, существенно влияющая на величину прибыльности магазина, которую необходимо учитывать при разработке маркетинговой стратегии интернет-магазина;
#
# 3) Текущая маркетинговая стратегия неэффективна - присутствуют категории товаров, из которых не осуществляется переход в другие категории (возможно, в таких категориях отсутствует рекламная кампания: не отображаются реклама, благодаря которой пользователь может перейти в заинтересовавший его блок, либо реклама не впечатлила клиента);
#
# 4) Пользователи категории "Растения и цветы" не совершают покупки товаров других категорий;
#
# 5) В некоторых месяцах полностью отсутствовали продажи товаров таких категорий, как "Гигиена", "Организация хранения", "Бытовая химияя", "Электрические товары";
#
# 6) По субботам отсутствуют продажи в категориях "Бытовая химия" и "Электрические товары".
#
# 7) В промежутке между 15:00 и 20:00 полностью отсутствуют продажи товаров категории "Организация хранения", в промежутке 16:00 и 18:00 отсутствуют продажи в категории "Бытовая химия".
#
# 8) Самая рентабельная категории с точки зрения продаж - категория "Растения и цветы", средний чек которой существенно ниже среднего чека товаров других категорий, что свидетельствует о том, что более "дешевые" товары оказываются рентабельнее "дорогих".
#
# 9) в предоставленном датасете было много неявных дубликатов, которые привели к завышению выручки магазина.
#
#
# На основании выявленных проблем, можно предложить следующие рекомендации:
#
# 1) повышение пользовательских метрик путем привлечения внимания аудитории различными маркетинговыми инструментами (рекламой, скидками постоянным клиентам, рассылкой на электронную почту и по смс сведений о специальных предложениях и акциях, поздравлениями с праздниками и предоставлением дополнительной скидки в честь праздника и т. д.);
#
# 2) пересмотреть ассортимент продаваемых товаров в категориях "Гигиена", "Организация хранения", "Бытовая химия", "Электрические товары", т. к. месяцами товары из данных категорий могут просто лежать на складе без продаж. Возможно, есть смысл изменить ассортимент товаров в данных группах или ценовую политику для стимуляции продаж.
#
# 3) пересмотреть существующую маркетинговую стратегию и инструменты для привлечения клиентов и стимуляции продаж (возможно, проводимая рекламная кампания является неэффективной, нужно дополнительно посмотреть на маркетинговый бюджет и рекламную кампанию);
#
# 4) проверить отображение контекстной рекламы и настройки интерфейса страницы в категории "Растения и цветы", т. к. клиенты из данной категории не осуществляют покупки товаров из других категорий. Возможно, что-то не так с рекламой или с переходом из данной категории в другие категории;
#
# 5) в маркетинговой стратегии необходимо также сезонность, присущую для магазина, и применить в каждом конкретном случае свой эффективный "маркетинговый" механизм.
#
# 6) повышение среднего чека заказа на отдельные категории товаров.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
# <div class="alert alert-success">
# <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# Здесь всё здорово.
# </p>
#     </div>
