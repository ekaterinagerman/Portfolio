# %% [markdown]
# # Дашборд для интернет-магазина товаров для дома и быта "Пока все еще тут"
#
# Для магазина подготовлен дашборд для определения количества покупок по дням.
# В дашборде представлены следующие графики:
#
# 1) Диаграмма количества покупок по дням;
#
# 2) Диаграмма процента заказа по продуктовым группам;
#
# 3) Диаграмма количества покупок по продуктовым группам за заданный период.
#
# Ссылка на дашборд: <https://public.tableau.com/app/profile/ekaterina.tinkova/viz/Purchasescountondailybasis-E-Commercedashboard/sheet4#1>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Екатерина, привет!
#
# Давай количество уникальных покупателей сделаем в виде отдельного числового индикатора. Основная идея - мы хотим под выбранный диапазон видеть, сколько у нас было уникальных покупателей. Строка на всплывающей подсказке нам такого не даст.
#
# Еще надо фильтр сделать по дате, там сейчас дата+время.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, добавила. Посмотри, пожалуйста. </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Екатерина, привет!
#
# С фильтром всё хорошо, а отдельный числовой индикатор - это отдельный объект на дашборде типа такого:
# </p>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <p>
# Не забудь настроить к нему фильтрацию.
# </p>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Екатерина Тинькова:</b> Готово, добавила. Посмотри, пожалуйста. </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">3</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Екатерина, привет!
#
# У нас какое-то недопонимание. Это бывает, попробуем наверстать. :) Следующую итерацию постараюсь сделать побыстрее. Смогу глянуть еще примерно через час, если не успеешь, то завтра утром.
#
# Я вот про этот индикатор.
# </p>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info"> <b> Екатерина Тинькова:</b> Да, действительно, вышло недопонимание. Добавила индикатор с покупателями :) </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">4</div>
# <div class="alert alert-block alert-success">
# <h4>Комментарий ревьюера: <a class="tocSkip"></h4>
# <p>
# Екатерина, привет!
#
# Всё отлично, молодец!
# </p>
# </div>
